# %%
import rdflib
from rdflib import Graph, URIRef, Literal, Namespace
from rdflib.namespace import RDF, OWL
from difflib import SequenceMatcher
from pprint import pprint
import ifcopenshell

# %%
ttl_ark = "C:/Users/yanpe/OneDrive - Metropolia Ammattikorkeakoulu Oy/Research/MD2MV/data/TTL/01ARK/ARK_MET.ttl"
ttl_rak = "C:/Users/yanpe/OneDrive - Metropolia Ammattikorkeakoulu Oy/Research/MD2MV/data/TTL/02RAK/RAK_MET.ttl"
ttl_lvi_iv = "C:/Users/yanpe/OneDrive - Metropolia Ammattikorkeakoulu Oy/Research/MD2MV/data/TTL/03LVI/LVI_IV_MET.ttl"

# %%
# --- Namespaces ---
# Adjust IFC namespace to match your specific file version (check file header!)
IFC = Namespace("https://standards.buildingsmart.org/IFC/DEV/IFC2x3/TC1/OWL#") 
BOT = Namespace("https://w3id.org/bot#")

def get_proxy_name(graph, subject):
    """
    Extracts the name from the URI object of owl:sameAs.
    Example: 
      Subject: inst:storey_GUID
      Predicate: owl:sameAs
      Object:  inst:IfcBuildingStorey_181
    Returns: "IfcBuildingStorey_181"
    """
    # 1. Check for owl:sameAs
    for o in graph.objects(subject, OWL.sameAs):
        # Convert URIRef to string (e.g., "http://.../IfcBuildingStorey_181")
        raw_uri = str(o)
        
        # 2. Extract the local name (fragment after last separator)
        if '#' in raw_uri:
            token = raw_uri.split('#')[-1]
        else:
            token = raw_uri.split('/')[-1]
            
        # Return the extracted ID immediately
        if token:
            return token

    # 3. Fallback: If no owl:sameAs, try standard Name property
    for p, o in graph.predicate_objects(subject):
        if "name" in str(p).lower() and isinstance(o, Literal):
            return str(o).strip()
            
    return "Unknown"

def extract_bot_skeleton(ttl_file_path, label):
    print(f"Parsing {label} ({ttl_file_path})...")
    g = Graph()
    g.parse(ttl_file_path, format="ttl")
    
    skeleton = {
        'sites': {}, 'buildings': {}, 'storeys': {}, 'spaces': {}
    }

    # Helper to populate dictionary
    def add_to_skeleton(rdf_type, target_dict):
        for s in g.subjects(RDF.type, rdf_type):
            # USE THE NEW PROXY NAME FUNCTION
            name = get_proxy_name(g, s)
            
            # Avoid overwriting if duplicates exist (though IDs should be unique)
            if name not in target_dict:
                target_dict[name] = s
            else:
                print(f"  [Warning] Duplicate ID found in {label}: {name}")

    # Extract all levels
    add_to_skeleton(BOT.Site, skeleton['sites'])
    add_to_skeleton(BOT.Building, skeleton['buildings'])
    add_to_skeleton(BOT.Storey, skeleton['storeys'])
    add_to_skeleton(BOT.Space, skeleton['spaces'])

    print(f"  Found: {len(skeleton['sites'])} Sites, {len(skeleton['buildings'])} Bldgs, "
          f"{len(skeleton['storeys'])} Storeys, {len(skeleton['spaces'])} Spaces")
    return skeleton

# %%
# --- Main Execution ---

# 1. Extract Skeletons
arch_data = extract_bot_skeleton(ttl_ark, "Architecture")
hvac_iv_data = extract_bot_skeleton(ttl_lvi_iv, "HVAC_IV")
rak_data = extract_bot_skeleton(ttl_rak, "Structure")
# Out:
# Parsing Architecture (C:/Users/yanpe/OneDrive - Metropolia Ammattikorkeakoulu Oy/Research/MD2MV/data/TTL/01ARK/ARK_MET.ttl)...
#   Found: 1 Sites, 1 Bldgs, 12 Storeys, 1404 Spaces
# Parsing HVAC_IV (C:/Users/yanpe/OneDrive - Metropolia Ammattikorkeakoulu Oy/Research/MD2MV/data/TTL/03LVI/LVI_IV_MET.ttl)...
#   Found: 1 Sites, 1 Bldgs, 9 Storeys, 0 Spaces
# Parsing Structure (C:/Users/yanpe/OneDrive - Metropolia Ammattikorkeakoulu Oy/Research/MD2MV/data/TTL/02RAK/RAK_MET.ttl)...
#   Found: 1 Sites, 8 Bldgs, 49 Storeys, 0 Spaces

# %%
pprint(arch_data)
# Out:
# {'buildings': {'IfcBuilding_118': rdflib.term.URIRef('https://lbd.example.com/building_28cb49f1-9b69-4870-aca3-d3f3628a7f64')},
#  'sites': {'IfcSite_23678881': rdflib.term.URIRef('https://lbd.example.com/site_28cb49f1-9b69-4870-aca3-d3f3628a7f67')},
#  'spaces': {'IfcSpace_1029': rdflib.term.URIRef('https://lbd.example.com/space_611eab86-f489-465e-bcd9-3a3dbbfc9996'),
#             'IfcSpace_10398': rdflib.term.URIRef('https://lbd.example.com/space_f90bef97-ba5a-4f16-a512-56b7145e3092'),
#             'IfcSpace_104011': rdflib.term.URIRef('https://lbd.example.com/space_df7623d4-2393-46f5-ad58-cefa159096e7'),
#             'IfcSpace_104781': rdflib.term.URIRef('https://lbd.example.com/space_df7623d4-2393-46f5-ad58-cefa1590a9c1'),
#             'IfcSpace_10552': rdflib.term.URIRef('https://lbd.example.com/space_f90bef97-ba5a-4f16-a512-56b7145e309d'),
#             'IfcSpace_105874': rdflib.term.URIRef('https://lbd.example.com/space_df7623d4-2393-46f5-ad58-cefa1590a837'),
#             'IfcSpace_108820': rdflib.term.URIRef('https://lbd.example.com/space_df7623d4-2393-46f5-ad58-cefa1590a83e'),
#             'IfcSpace_110073': rdflib.term.URIRef('https://lbd.example.com/space_89824dc2-1ac9-40f2-a711-9fef4061ef1c'),
#             'IfcSpace_111284': rdflib.term.URIRef('https://lbd.example.com/space_89824dc2-1ac9-40f2-a711-9fef4061ef14'),
#             'IfcSpace_111513': rdflib.term.URIRef('https://lbd.example.com/space_1fc2eb16-637f-4481-afe5-2dc53514d1b3'),
#             'IfcSpace_111734': rdflib.term.URIRef('https://lbd.example.com/space_1fc2eb16-637f-4481-afe5-2dc53514d1b2'),
#             'IfcSpace_112090': rdflib.term.URIRef('https://lbd.example.com/space_1fc2eb16-637f-4481-afe5-2dc53514d1b1'),
#             'IfcSpace_112249': rdflib.term.URIRef('https://lbd.example.com/space_1fc2eb16-637f-4481-afe5-2dc53514d1b5'),
#             'IfcSpace_112426': rdflib.term.URIRef('https://lbd.example.com/space_1fc2eb16-637f-4481-afe5-2dc53514df70'),
#             'IfcSpace_112571': rdflib.term.URIRef('https://lbd.example.com/space_1fc2eb16-637f-4481-afe5-2dc53514df53'),
#             'IfcSpace_113912': rdflib.term.URIRef('https://lbd.example.com/space_1fc2eb16-637f-4481-afe5-2dc53514de5b'),
#             'IfcSpace_114016': rdflib.term.URIRef('https://lbd.example.com/space_1fc2eb16-637f-4481-afe5-2dc53514de55'),
#             'IfcSpace_115515': rdflib.term.URIRef('https://lbd.example.com/space_1fc2eb16-637f-4481-afe5-2dc53514de4c'),
#             'IfcSpace_116092': rdflib.term.URIRef('https://lbd.example.com/space_1fc2eb16-637f-4481-afe5-2dc53514ddba'),
#             'IfcSpace_116489': rdflib.term.URIRef('https://lbd.example.com/space_1fc2eb16-637f-4481-afe5-2dc53514dd0d'),
#             'IfcSpace_117913': rdflib.term.URIRef('https://lbd.example.com/space_1fc2eb16-637f-4481-afe5-2dc53514dcea'),
#             'IfcSpace_11979': rdflib.term.URIRef('https://lbd.example.com/space_f90bef97-ba5a-4f16-a512-56b7145e309c'),
#             'IfcSpace_123695': rdflib.term.URIRef('https://lbd.example.com/space_1fc2eb16-637f-4481-afe5-2dc53514dc1d'),
#             'IfcSpace_124331': rdflib.term.URIRef('https://lbd.example.com/space_1fc2eb16-637f-4481-afe5-2dc53514dc50'),
#             'IfcSpace_124609': rdflib.term.URIRef('https://lbd.example.com/space_1fc2eb16-637f-4481-afe5-2dc53514d9bc'),
#             'IfcSpace_124717': rdflib.term.URIRef('https://lbd.example.com/space_1fc2eb16-637f-4481-afe5-2dc53514d936'),
#             'IfcSpace_124829': rdflib.term.URIRef('https://lbd.example.com/space_1fc2eb16-637f-4481-afe5-2dc53514d92e'),
#             'IfcSpace_126337': rdflib.term.URIRef('https://lbd.example.com/space_0a3c4dc1-f129-4bef-a0fd-9183303d5df7'),
#             'IfcSpace_126607': rdflib.term.URIRef('https://lbd.example.com/space_634f8fd8-9c65-4f8f-9719-0c5291f8f2ab'),
#             'IfcSpace_126717': rdflib.term.URIRef('https://lbd.example.com/space_f6d08663-9e35-49ca-bc1e-d572b86d606c'),
#             'IfcSpace_127531': rdflib.term.URIRef('https://lbd.example.com/space_f6d08663-9e35-49ca-bc1e-d572b86d6019'),
#             'IfcSpace_127622': rdflib.term.URIRef('https://lbd.example.com/space_f6d08663-9e35-49ca-bc1e-d572b86d6012'),
#             'IfcSpace_127721': rdflib.term.URIRef('https://lbd.example.com/space_ed839a73-bd11-47f7-bd60-ffd909258cfb'),
#             'IfcSpace_127823': rdflib.term.URIRef('https://lbd.example.com/space_b2df46ec-c422-42e5-b176-c5dbadb74d69'),
#             'IfcSpace_127915': rdflib.term.URIRef('https://lbd.example.com/space_b2df46ec-c422-42e5-b176-c5dbadb74d76'),
#             'IfcSpace_128022': rdflib.term.URIRef('https://lbd.example.com/space_b2df46ec-c422-42e5-b176-c5dbadb74d03'),
#             'IfcSpace_128129': rdflib.term.URIRef('https://lbd.example.com/space_b2df46ec-c422-42e5-b176-c5dbadb74d08'),
#             'IfcSpace_128221': rdflib.term.URIRef('https://lbd.example.com/space_b2df46ec-c422-42e5-b176-c5dbadb74d15'),
#             'IfcSpace_135202': rdflib.term.URIRef('https://lbd.example.com/space_2a48634d-1f4a-414b-9455-d72e4995242c'),
#             'IfcSpace_135551': rdflib.term.URIRef('https://lbd.example.com/space_7dd8281c-bb50-402e-bb15-6d48df9b5ab4'),
#             'IfcSpace_136851': rdflib.term.URIRef('https://lbd.example.com/space_7dd8281c-bb50-402e-bb15-6d48df9b5b4c'),
#             'IfcSpace_137630': rdflib.term.URIRef('https://lbd.example.com/space_7dd8281c-bb50-402e-bb15-6d48df9b5b45'),
#             'IfcSpace_137729': rdflib.term.URIRef('https://lbd.example.com/space_7dd8281c-bb50-402e-bb15-6d48df9b5b52'),
#             'IfcSpace_138147': rdflib.term.URIRef('https://lbd.example.com/space_7dd8281c-bb50-402e-bb15-6d48df9b5b6c'),
#             'IfcSpace_138352': rdflib.term.URIRef('https://lbd.example.com/space_7dd8281c-bb50-402e-bb15-6d48df9b5b7a'),
#             'IfcSpace_139380': rdflib.term.URIRef('https://lbd.example.com/space_b4a3c5ef-883b-41f1-bb68-8cc882cf6d6a'),
#             'IfcSpace_140904': rdflib.term.URIRef('https://lbd.example.com/space_b4a3c5ef-883b-41f1-bb68-8cc882cf6d58'),
#             'IfcSpace_141129': rdflib.term.URIRef('https://lbd.example.com/space_b4a3c5ef-883b-41f1-bb68-8cc882cf6db2'),
#             'IfcSpace_141383': rdflib.term.URIRef('https://lbd.example.com/space_b4a3c5ef-883b-41f1-bb68-8cc882cf6da7'),
#             'IfcSpace_141713': rdflib.term.URIRef('https://lbd.example.com/space_b4a3c5ef-883b-41f1-bb68-8cc882cf6dfe'),
#             'IfcSpace_142410': rdflib.term.URIRef('https://lbd.example.com/space_90857e64-176c-4b1e-b4c1-47ec8b80718d'),
#             'IfcSpace_142510': rdflib.term.URIRef('https://lbd.example.com/space_07e9418c-4a43-467c-a741-08289b99dbd9'),
#             'IfcSpace_142925': rdflib.term.URIRef('https://lbd.example.com/space_61989a79-467a-4d07-870d-7acf1ccaf2ba'),
#             'IfcSpace_143153': rdflib.term.URIRef('https://lbd.example.com/space_61989a79-467a-4d07-870d-7acf1ccaf2c9'),
#             'IfcSpace_143256': rdflib.term.URIRef('https://lbd.example.com/space_61989a79-467a-4d07-870d-7acf1ccaf2e5'),
#             'IfcSpace_143365': rdflib.term.URIRef('https://lbd.example.com/space_61989a79-467a-4d07-870d-7acf1ccaf2f8'),
#             'IfcSpace_143477': rdflib.term.URIRef('https://lbd.example.com/space_61989a79-467a-4d07-870d-7acf1ccaf30c'),
#             'IfcSpace_144135': rdflib.term.URIRef('https://lbd.example.com/space_1ae28167-216c-4750-b984-f7b4c02ca745'),
#             'IfcSpace_144364': rdflib.term.URIRef('https://lbd.example.com/space_1ae28167-216c-4750-b984-f7b4c02ca74a'),
#             'IfcSpace_144474': rdflib.term.URIRef('https://lbd.example.com/space_1ae28167-216c-4750-b984-f7b4c02ca750'),
#             'IfcSpace_144855': rdflib.term.URIRef('https://lbd.example.com/space_63211009-ff12-4d9a-bdb5-a6f0d3b487f1'),
#             'IfcSpace_147743': rdflib.term.URIRef('https://lbd.example.com/space_b019fbfa-19e6-4720-b844-94fef91a9c80'),
#             'IfcSpace_148487': rdflib.term.URIRef('https://lbd.example.com/space_d621efe8-1cb0-4498-9d35-1e487a56a731'),
#             'IfcSpace_148608': rdflib.term.URIRef('https://lbd.example.com/space_5dcdfe5b-ded1-4425-8b13-7fa69efdb2d2'),
#             'IfcSpace_154883': rdflib.term.URIRef('https://lbd.example.com/space_83ae07db-0d76-427e-be44-c8d3355c68cf'),
#             'IfcSpace_156186': rdflib.term.URIRef('https://lbd.example.com/space_83ae07db-0d76-427e-be44-c8d3355c68ec'),
#             'IfcSpace_156872': rdflib.term.URIRef('https://lbd.example.com/space_83ae07db-0d76-427e-be44-c8d3355c69a7'),
#             'IfcSpace_157701': rdflib.term.URIRef('https://lbd.example.com/space_83ae07db-0d76-427e-be44-c8d3355c69db'),
#             'IfcSpace_158766': rdflib.term.URIRef('https://lbd.example.com/space_83ae07db-0d76-427e-be44-c8d3355c6a60'),
#             'IfcSpace_159704': rdflib.term.URIRef('https://lbd.example.com/space_83ae07db-0d76-427e-be44-c8d3355c6a8e'),
#             'IfcSpace_161113': rdflib.term.URIRef('https://lbd.example.com/space_50469c64-753f-4f17-bd0d-de807cd78159'),
#             'IfcSpace_161219': rdflib.term.URIRef('https://lbd.example.com/space_50469c64-753f-4f17-bd0d-de807cd780ba'),
#             'IfcSpace_161878': rdflib.term.URIRef('https://lbd.example.com/space_bdb3def3-c5d4-4193-aa4b-22a5727cc321'),
#             'IfcSpace_162182': rdflib.term.URIRef('https://lbd.example.com/space_1b5e3d9a-a9c9-4971-8f99-78691b7e2580'),
#             'IfcSpace_162469': rdflib.term.URIRef('https://lbd.example.com/space_1b5e3d9a-a9c9-4971-8f99-78691b7e2597'),
#             'IfcSpace_163510': rdflib.term.URIRef('https://lbd.example.com/space_10c261c7-d67d-43e9-bb1d-57f7f5b01a5a'),
#             'IfcSpace_163708': rdflib.term.URIRef('https://lbd.example.com/space_10c261c7-d67d-43e9-bb1d-57f7f5b01a4f'),
#             'IfcSpace_165368': rdflib.term.URIRef('https://lbd.example.com/space_cf913309-95e7-47ed-8f3a-69780aa3d0fb'),
#             'IfcSpace_165565': rdflib.term.URIRef('https://lbd.example.com/space_cf913309-95e7-47ed-8f3a-69780aa3d0cb'),
#             'IfcSpace_16592': rdflib.term.URIRef('https://lbd.example.com/space_f90bef97-ba5a-4f16-a512-56b7145e30c6'),
#             'IfcSpace_165956': rdflib.term.URIRef('https://lbd.example.com/space_cf913309-95e7-47ed-8f3a-69780aa3d071'),
#             'IfcSpace_166129': rdflib.term.URIRef('https://lbd.example.com/space_cf913309-95e7-47ed-8f3a-69780aa3d185'),
#             'IfcSpace_166236': rdflib.term.URIRef('https://lbd.example.com/space_cf913309-95e7-47ed-8f3a-69780aa3d18f'),
#             'IfcSpace_166348': rdflib.term.URIRef('https://lbd.example.com/space_cf913309-95e7-47ed-8f3a-69780aa3d106'),
#             'IfcSpace_166556': rdflib.term.URIRef('https://lbd.example.com/space_30c47afd-1bed-4c06-8146-389addb98b86'),
#             'IfcSpace_168165': rdflib.term.URIRef('https://lbd.example.com/space_228e41b7-24c4-475f-bbae-fead44718774'),
#             'IfcSpace_168269': rdflib.term.URIRef('https://lbd.example.com/space_1ba7532c-9d71-4788-90c7-f950a07be30e'),
#             'IfcSpace_172141': rdflib.term.URIRef('https://lbd.example.com/space_1ba7532c-9d71-4788-90c7-f950a07be345'),
#             'IfcSpace_172620': rdflib.term.URIRef('https://lbd.example.com/space_1ba7532c-9d71-4788-90c7-f950a07be3a8'),
#             'IfcSpace_172790': rdflib.term.URIRef('https://lbd.example.com/space_e6c1b2c8-3087-435b-bdad-970fd7edaeea'),
#             'IfcSpace_173689': rdflib.term.URIRef('https://lbd.example.com/space_c8117ec0-f257-41a2-ac09-4e14d23f96c8'),
#             'IfcSpace_174843': rdflib.term.URIRef('https://lbd.example.com/space_c323435b-048f-4364-ba86-cb4f41b045ac'),
#             'IfcSpace_174990': rdflib.term.URIRef('https://lbd.example.com/space_c323435b-048f-4364-ba86-cb4f41b045fa'),
#             'IfcSpace_17505': rdflib.term.URIRef('https://lbd.example.com/space_f90bef97-ba5a-4f16-a512-56b7145e30e3'),
#             'IfcSpace_175760': rdflib.term.URIRef('https://lbd.example.com/space_c323435b-048f-4364-ba86-cb4f41b0440f'),
#             'IfcSpace_175950': rdflib.term.URIRef('https://lbd.example.com/space_c323435b-048f-4364-ba86-cb4f41b04737'),
#             'IfcSpace_176095': rdflib.term.URIRef('https://lbd.example.com/space_c323435b-048f-4364-ba86-cb4f41b04756'),
#             'IfcSpace_176285': rdflib.term.URIRef('https://lbd.example.com/space_c323435b-048f-4364-ba86-cb4f41b0479e'),
#             'IfcSpace_177518': rdflib.term.URIRef('https://lbd.example.com/space_c323435b-048f-4364-ba86-cb4f41b0465c'),
#             'IfcSpace_177700': rdflib.term.URIRef('https://lbd.example.com/space_c323435b-048f-4364-ba86-cb4f41b0466d'),
#             'IfcSpace_177845': rdflib.term.URIRef('https://lbd.example.com/space_c323435b-048f-4364-ba86-cb4f41b04694'),
#             'IfcSpace_178368': rdflib.term.URIRef('https://lbd.example.com/space_c323435b-048f-4364-ba86-cb4f41b046b2'),
#             'IfcSpace_179780': rdflib.term.URIRef('https://lbd.example.com/space_c323435b-048f-4364-ba86-cb4f41b046a2'),
#             'IfcSpace_18360': rdflib.term.URIRef('https://lbd.example.com/space_f90bef97-ba5a-4f16-a512-56b7145e31c1'),
#             'IfcSpace_18473': rdflib.term.URIRef('https://lbd.example.com/space_f90bef97-ba5a-4f16-a512-56b7145e3106'),
#             'IfcSpace_184778': rdflib.term.URIRef('https://lbd.example.com/space_246c0945-d763-4ee3-904e-b12ce0c01a1d'),
#             'IfcSpace_189366': rdflib.term.URIRef('https://lbd.example.com/space_a3528cbb-3683-4b22-8741-9a782c3c2bb8'),
#             'IfcSpace_189474': rdflib.term.URIRef('https://lbd.example.com/space_484e653b-1543-41df-8f7e-eda52563e4ad'),
#             'IfcSpace_189940': rdflib.term.URIRef('https://lbd.example.com/space_c5030342-46fc-436c-87ff-05726d5b68e1'),
#             'IfcSpace_19073': rdflib.term.URIRef('https://lbd.example.com/space_f90bef97-ba5a-4f16-a512-56b7145e315c'),
#             'IfcSpace_19329': rdflib.term.URIRef('https://lbd.example.com/space_f90bef97-ba5a-4f16-a512-56b7145e362f'),
#             'IfcSpace_19471': rdflib.term.URIRef('https://lbd.example.com/space_f90bef97-ba5a-4f16-a512-56b7145e3499'),
#             'IfcSpace_19580': rdflib.term.URIRef('https://lbd.example.com/space_f90bef97-ba5a-4f16-a512-56b7145e34be'),
#             'IfcSpace_197038': rdflib.term.URIRef('https://lbd.example.com/space_15b7968a-0076-4e45-b1e9-fb6346ec4a96'),
#             'IfcSpace_197234': rdflib.term.URIRef('https://lbd.example.com/space_56a533c1-7974-4c99-a10c-b64e1c1360f5'),
#             'IfcSpace_197333': rdflib.term.URIRef('https://lbd.example.com/space_efd697f6-50c9-40a6-91ef-59cf6dadec6c'),
#             'IfcSpace_197428': rdflib.term.URIRef('https://lbd.example.com/space_efd697f6-50c9-40a6-91ef-59cf6dadec79'),
#             'IfcSpace_19810': rdflib.term.URIRef('https://lbd.example.com/space_f90bef97-ba5a-4f16-a512-56b7145e34dc'),
#             'IfcSpace_200876': rdflib.term.URIRef('https://lbd.example.com/space_8993ce47-0828-4912-8f90-dc5b85b6866a'),
#             'IfcSpace_201581': rdflib.term.URIRef('https://lbd.example.com/space_8993ce47-0828-4912-8f90-dc5b85b686d2'),
#             'IfcSpace_201804': rdflib.term.URIRef('https://lbd.example.com/space_5866dfbf-a22a-4ad8-8abe-bf42e127fe17'),
#             'IfcSpace_202017': rdflib.term.URIRef('https://lbd.example.com/space_5866dfbf-a22a-4ad8-8abe-bf42e127fe0e'),
#             'IfcSpace_202163': rdflib.term.URIRef('https://lbd.example.com/space_5866dfbf-a22a-4ad8-8abe-bf42e127fe7c'),
#             'IfcSpace_202269': rdflib.term.URIRef('https://lbd.example.com/space_5866dfbf-a22a-4ad8-8abe-bf42e127fe66'),
#             'IfcSpace_202373': rdflib.term.URIRef('https://lbd.example.com/space_5866dfbf-a22a-4ad8-8abe-bf42e127feb6'),
#             'IfcSpace_202591': rdflib.term.URIRef('https://lbd.example.com/space_5866dfbf-a22a-4ad8-8abe-bf42e127fea4'),
#             'IfcSpace_20262': rdflib.term.URIRef('https://lbd.example.com/space_f90bef97-ba5a-4f16-a512-56b7145e34ea'),
#             'IfcSpace_202808': rdflib.term.URIRef('https://lbd.example.com/space_44a7052e-63a0-49fb-922a-5369254829a3'),
#             'IfcSpace_202899': rdflib.term.URIRef('https://lbd.example.com/space_44a7052e-63a0-49fb-922a-5369254829a4'),
#             'IfcSpace_203227': rdflib.term.URIRef('https://lbd.example.com/space_e0628474-5ec8-4e54-85d5-aa42b9450657'),
#             'IfcSpace_203399': rdflib.term.URIRef('https://lbd.example.com/space_9949f1af-8d92-48f1-93b5-07acf44010b4'),
#             'IfcSpace_203585': rdflib.term.URIRef('https://lbd.example.com/space_9949f1af-8d92-48f1-93b5-07acf44010ab'),
#             'IfcSpace_20428': rdflib.term.URIRef('https://lbd.example.com/space_f90bef97-ba5a-4f16-a512-56b7145e346e'),
#             'IfcSpace_204965': rdflib.term.URIRef('https://lbd.example.com/space_9075ec05-0e90-4480-b33e-e900811d0b6c'),
#             'IfcSpace_20567': rdflib.term.URIRef('https://lbd.example.com/space_f90bef97-ba5a-4f16-a512-56b7145e347b'),
#             'IfcSpace_205858': rdflib.term.URIRef('https://lbd.example.com/space_9075ec05-0e90-4480-b33e-e900811d0b7f'),
#             'IfcSpace_20679': rdflib.term.URIRef('https://lbd.example.com/space_f90bef97-ba5a-4f16-a512-56b7145e3597'),
#             'IfcSpace_206855': rdflib.term.URIRef('https://lbd.example.com/space_9075ec05-0e90-4480-b33e-e900811d0b8b'),
#             'IfcSpace_206956': rdflib.term.URIRef('https://lbd.example.com/space_50bc44b1-87f3-4b75-9686-c9f63429a0cf'),
#             'IfcSpace_20862': rdflib.term.URIRef('https://lbd.example.com/space_f90bef97-ba5a-4f16-a512-56b7145e35a3'),
#             'IfcSpace_20972': rdflib.term.URIRef('https://lbd.example.com/space_f90bef97-ba5a-4f16-a512-56b7145e35a8'),
#             'IfcSpace_21094': rdflib.term.URIRef('https://lbd.example.com/space_f90bef97-ba5a-4f16-a512-56b7145e35b0'),
#             'IfcSpace_211503': rdflib.term.URIRef('https://lbd.example.com/space_50bc44b1-87f3-4b75-9686-c9f63429a0f8'),
#             'IfcSpace_21215': rdflib.term.URIRef('https://lbd.example.com/space_f90bef97-ba5a-4f16-a512-56b7145e35b8'),
#             'IfcSpace_213030': rdflib.term.URIRef('https://lbd.example.com/space_0539fe6c-26bf-443a-bcf2-e69da60aa009'),
#             'IfcSpace_213146': rdflib.term.URIRef('https://lbd.example.com/space_38249334-a279-4150-9a64-edf5205ccf15'),
#             'IfcSpace_21322': rdflib.term.URIRef('https://lbd.example.com/space_f90bef97-ba5a-4f16-a512-56b7145e35f7'),
#             'IfcSpace_213253': rdflib.term.URIRef('https://lbd.example.com/space_38249334-a279-4150-9a64-edf5205ccf0a'),
#             'IfcSpace_213343': rdflib.term.URIRef('https://lbd.example.com/space_38249334-a279-4150-9a64-edf5205ccf22'),
#             'IfcSpace_213454': rdflib.term.URIRef('https://lbd.example.com/space_38249334-a279-4150-9a64-edf5205ccfd5'),
#             'IfcSpace_21423': rdflib.term.URIRef('https://lbd.example.com/space_f90bef97-ba5a-4f16-a512-56b7145e35fd'),
#             'IfcSpace_21524': rdflib.term.URIRef('https://lbd.example.com/space_f90bef97-ba5a-4f16-a512-56b7145e2bb4'),
#             'IfcSpace_216134': rdflib.term.URIRef('https://lbd.example.com/space_f6847b71-dbf9-4a84-ba85-25d5716d1975'),
#             'IfcSpace_21621': rdflib.term.URIRef('https://lbd.example.com/space_f90bef97-ba5a-4f16-a512-56b7145e2b1e'),
#             'IfcSpace_216319': rdflib.term.URIRef('https://lbd.example.com/space_8d4f125f-257e-4cb7-a724-325d2965b69f'),
#             'IfcSpace_216503': rdflib.term.URIRef('https://lbd.example.com/space_8d4f125f-257e-4cb7-a724-325d2965b676'),
#             'IfcSpace_217445': rdflib.term.URIRef('https://lbd.example.com/space_8d4f125f-257e-4cb7-a724-325d2965b66d'),
#             'IfcSpace_218640': rdflib.term.URIRef('https://lbd.example.com/space_8d4f125f-257e-4cb7-a724-325d2965b654'),
#             'IfcSpace_218838': rdflib.term.URIRef('https://lbd.example.com/space_8d4f125f-257e-4cb7-a724-325d2965b65f'),
#             'IfcSpace_22167': rdflib.term.URIRef('https://lbd.example.com/space_f90bef97-ba5a-4f16-a512-56b7145e2b3a'),
#             'IfcSpace_225735': rdflib.term.URIRef('https://lbd.example.com/space_8d4f125f-257e-4cb7-a724-325d2965b64e'),
#             'IfcSpace_227511': rdflib.term.URIRef('https://lbd.example.com/space_8d4f125f-257e-4cb7-a724-325d2965b631'),
#             'IfcSpace_227908': rdflib.term.URIRef('https://lbd.example.com/space_8d4f125f-257e-4cb7-a724-325d2965b638'),
#             'IfcSpace_228847': rdflib.term.URIRef('https://lbd.example.com/space_8d4f125f-257e-4cb7-a724-325d2965b620'),
#             'IfcSpace_229030': rdflib.term.URIRef('https://lbd.example.com/space_8d4f125f-257e-4cb7-a724-325d2965b615'),
#             'IfcSpace_230109': rdflib.term.URIRef('https://lbd.example.com/space_8d4f125f-257e-4cb7-a724-325d2965b60b'),
#             'IfcSpace_23236': rdflib.term.URIRef('https://lbd.example.com/space_c54f5ba5-100f-48cb-be39-360f87f64746'),
#             'IfcSpace_232853': rdflib.term.URIRef('https://lbd.example.com/space_8f8f3067-d923-4381-b66b-cb27738b3285'),
#             'IfcSpace_233194': rdflib.term.URIRef('https://lbd.example.com/space_0dd2fa0d-81a2-44b9-a125-130da0324e1e'),
#             'IfcSpace_233493': rdflib.term.URIRef('https://lbd.example.com/space_45dfd26a-6f07-4dcf-a8ac-17486a056b27'),
#             'IfcSpace_235843': rdflib.term.URIRef('https://lbd.example.com/space_204ebc52-2b8e-4fa7-95c1-0436438d2401'),
#             'IfcSpace_236035': rdflib.term.URIRef('https://lbd.example.com/space_038a13b2-f7d3-49b3-9d3d-772434e8cdb3'),
#             'IfcSpace_238020': rdflib.term.URIRef('https://lbd.example.com/space_22ed7fc5-019d-4df2-a521-0c0c08a1a419'),
#             'IfcSpace_238252': rdflib.term.URIRef('https://lbd.example.com/space_e95660b8-c68a-4685-9f25-41c820000053'),
#             'IfcSpace_238425': rdflib.term.URIRef('https://lbd.example.com/space_e95660b8-c68a-4685-9f25-41c820000038'),
#             'IfcSpace_238732': rdflib.term.URIRef('https://lbd.example.com/space_21f2dc47-5400-4aa9-848b-d33626c17e3f'),
#             'IfcSpace_238965': rdflib.term.URIRef('https://lbd.example.com/space_21f2dc47-5400-4aa9-848b-d33626c17f4a'),
#             'IfcSpace_239634': rdflib.term.URIRef('https://lbd.example.com/space_21f2dc47-5400-4aa9-848b-d33626c17f64'),
#             'IfcSpace_240380': rdflib.term.URIRef('https://lbd.example.com/space_21f2dc47-5400-4aa9-848b-d33626c17f0c'),
#             'IfcSpace_240470': rdflib.term.URIRef('https://lbd.example.com/space_bd84cf12-85b7-4c7d-a325-9b27e25a1177'),
#             'IfcSpace_240572': rdflib.term.URIRef('https://lbd.example.com/space_cb722760-bdf4-43f0-8438-fc6968be24f7'),
#             'IfcSpace_240665': rdflib.term.URIRef('https://lbd.example.com/space_cb722760-bdf4-43f0-8438-fc6968be24f8'),
#             'IfcSpace_240757': rdflib.term.URIRef('https://lbd.example.com/space_cb722760-bdf4-43f0-8438-fc6968be24fd'),
#             'IfcSpace_240866': rdflib.term.URIRef('https://lbd.example.com/space_cb722760-bdf4-43f0-8438-fc6968be24e9'),
#             'IfcSpace_241292': rdflib.term.URIRef('https://lbd.example.com/space_5c743574-1409-49e6-96be-7b3423b927d4'),
#             'IfcSpace_241916': rdflib.term.URIRef('https://lbd.example.com/space_f69a19db-32a3-45a8-a628-110816544d1e'),
#             'IfcSpace_242028': rdflib.term.URIRef('https://lbd.example.com/space_f69a19db-32a3-45a8-a628-110816544d1a'),
#             'IfcSpace_242215': rdflib.term.URIRef('https://lbd.example.com/space_f69a19db-32a3-45a8-a628-110816544d03'),
#             'IfcSpace_243137': rdflib.term.URIRef('https://lbd.example.com/space_f69a19db-32a3-45a8-a628-110816544d08'),
#             'IfcSpace_243361': rdflib.term.URIRef('https://lbd.example.com/space_f69a19db-32a3-45a8-a628-110816544d3f'),
#             'IfcSpace_243586': rdflib.term.URIRef('https://lbd.example.com/space_f69a19db-32a3-45a8-a628-110816544d23'),
#             'IfcSpace_243697': rdflib.term.URIRef('https://lbd.example.com/space_f69a19db-32a3-45a8-a628-110816544dd7'),
#             'IfcSpace_243869': rdflib.term.URIRef('https://lbd.example.com/space_f69a19db-32a3-45a8-a628-110816544ddb'),
#             'IfcSpace_244829': rdflib.term.URIRef('https://lbd.example.com/space_f69a19db-32a3-45a8-a628-110816544df5'),
#             'IfcSpace_245173': rdflib.term.URIRef('https://lbd.example.com/space_f69a19db-32a3-45a8-a628-110816544c2d'),
#             'IfcSpace_245336': rdflib.term.URIRef('https://lbd.example.com/space_f69a19db-32a3-45a8-a628-110816544cdc'),
#             'IfcSpace_246780': rdflib.term.URIRef('https://lbd.example.com/space_f69a19db-32a3-45a8-a628-110816544cee'),
#             'IfcSpace_24820': rdflib.term.URIRef('https://lbd.example.com/space_c54f5ba5-100f-48cb-be39-360f87f6478f'),
#             'IfcSpace_248282': rdflib.term.URIRef('https://lbd.example.com/space_f69a19db-32a3-45a8-a628-110816544cb5'),
#             'IfcSpace_248748': rdflib.term.URIRef('https://lbd.example.com/space_f69a19db-32a3-45a8-a628-1108165443af'),
#             'IfcSpace_248949': rdflib.term.URIRef('https://lbd.example.com/space_f69a19db-32a3-45a8-a628-1108165442f1'),
#             'IfcSpace_249103': rdflib.term.URIRef('https://lbd.example.com/space_f69a19db-32a3-45a8-a628-110816544079'),
#             'IfcSpace_249396': rdflib.term.URIRef('https://lbd.example.com/space_f69a19db-32a3-45a8-a628-1108165440a1'),
#             'IfcSpace_249543': rdflib.term.URIRef('https://lbd.example.com/space_f69a19db-32a3-45a8-a628-110816544700'),
#             'IfcSpace_24974': rdflib.term.URIRef('https://lbd.example.com/space_c54f5ba5-100f-48cb-be39-360f87f647e7'),
#             'IfcSpace_250618': rdflib.term.URIRef('https://lbd.example.com/space_f69a19db-32a3-45a8-a628-110816544731'),
#             'IfcSpace_250765': rdflib.term.URIRef('https://lbd.example.com/space_f69a19db-32a3-45a8-a628-1108165447d6'),
#             'IfcSpace_250890': rdflib.term.URIRef('https://lbd.example.com/space_f69a19db-32a3-45a8-a628-110816544604'),
#             'IfcSpace_251004': rdflib.term.URIRef('https://lbd.example.com/space_ef959890-f97e-4e88-a790-e8cf17002144'),
#             'IfcSpace_251432': rdflib.term.URIRef('https://lbd.example.com/space_ef959890-f97e-4e88-a790-e8cf17002154'),
#             'IfcSpace_251592': rdflib.term.URIRef('https://lbd.example.com/space_ef959890-f97e-4e88-a790-e8cf170022a1'),
#             'IfcSpace_252530': rdflib.term.URIRef('https://lbd.example.com/space_ef959890-f97e-4e88-a790-e8cf170022b7'),
#             'IfcSpace_252682': rdflib.term.URIRef('https://lbd.example.com/space_ef959890-f97e-4e88-a790-e8cf1700227d'),
#             'IfcSpace_252933': rdflib.term.URIRef('https://lbd.example.com/space_ef959890-f97e-4e88-a790-e8cf17002243'),
#             'IfcSpace_253106': rdflib.term.URIRef('https://lbd.example.com/space_ef959890-f97e-4e88-a790-e8cf170023ce'),
#             'IfcSpace_253278': rdflib.term.URIRef('https://lbd.example.com/space_ef959890-f97e-4e88-a790-e8cf1700232f'),
#             'IfcSpace_254002': rdflib.term.URIRef('https://lbd.example.com/space_ef959890-f97e-4e88-a790-e8cf1700233d'),
#             'IfcSpace_254123': rdflib.term.URIRef('https://lbd.example.com/space_54b1fc5c-11d3-48c0-8242-878a4b8f2590'),
#             'IfcSpace_254357': rdflib.term.URIRef('https://lbd.example.com/space_54b1fc5c-11d3-48c0-8242-878a4b8f2606'),
#             'IfcSpace_25696': rdflib.term.URIRef('https://lbd.example.com/space_c54f5ba5-100f-48cb-be39-360f87f647cf'),
#             'IfcSpace_257098': rdflib.term.URIRef('https://lbd.example.com/space_7282ee0d-92e7-4cdf-8a65-87e4632dd0ac'),
#             'IfcSpace_257657': rdflib.term.URIRef('https://lbd.example.com/space_7282ee0d-92e7-4cdf-8a65-87e4632dd086'),
#             'IfcSpace_261875': rdflib.term.URIRef('https://lbd.example.com/space_7282ee0d-92e7-4cdf-8a65-87e4632dd06a'),
#             'IfcSpace_261979': rdflib.term.URIRef('https://lbd.example.com/space_71ca44aa-5eb4-467d-9fb4-a994991727f3'),
#             'IfcSpace_262965': rdflib.term.URIRef('https://lbd.example.com/space_71ca44aa-5eb4-467d-9fb4-a99499171828'),
#             'IfcSpace_263069': rdflib.term.URIRef('https://lbd.example.com/space_31a11421-7d99-4331-8adc-1f8b94565eec'),
#             'IfcSpace_263207': rdflib.term.URIRef('https://lbd.example.com/space_32c1c1c5-f4dd-47ec-a94f-d032174cbad5'),
#             'IfcSpace_263510': rdflib.term.URIRef('https://lbd.example.com/space_32c1c1c5-f4dd-47ec-a94f-d032174cbbec'),
#             'IfcSpace_263752': rdflib.term.URIRef('https://lbd.example.com/space_f2f31c4d-298d-4587-b54f-472d48e408d3'),
#             'IfcSpace_2648': rdflib.term.URIRef('https://lbd.example.com/space_f90bef97-ba5a-4f16-a512-56b7145e338c'),
#             'IfcSpace_264839': rdflib.term.URIRef('https://lbd.example.com/space_5846f51d-5ade-4382-8ef9-a582961717fe'),
#             'IfcSpace_265968': rdflib.term.URIRef('https://lbd.example.com/space_5846f51d-5ade-4382-8ef9-a582961717e6'),
#             'IfcSpace_26672': rdflib.term.URIRef('https://lbd.example.com/space_c54f5ba5-100f-48cb-be39-360f87f647c5'),
#             'IfcSpace_267335': rdflib.term.URIRef('https://lbd.example.com/space_5846f51d-5ade-4382-8ef9-a58296171772'),
#             'IfcSpace_267439': rdflib.term.URIRef('https://lbd.example.com/space_5846f51d-5ade-4382-8ef9-a58296171760'),
#             'IfcSpace_27254': rdflib.term.URIRef('https://lbd.example.com/space_c54f5ba5-100f-48cb-be39-360f87f6463c'),
#             'IfcSpace_27579': rdflib.term.URIRef('https://lbd.example.com/space_c54f5ba5-100f-48cb-be39-360f87f6462a'),
#             'IfcSpace_275848': rdflib.term.URIRef('https://lbd.example.com/space_5846f51d-5ade-4382-8ef9-a5829617176c'),
#             'IfcSpace_276274': rdflib.term.URIRef('https://lbd.example.com/space_5846f51d-5ade-4382-8ef9-a58296171715'),
#             'IfcSpace_276454': rdflib.term.URIRef('https://lbd.example.com/space_5846f51d-5ade-4382-8ef9-a5829617173d'),
#             'IfcSpace_276721': rdflib.term.URIRef('https://lbd.example.com/space_5846f51d-5ade-4382-8ef9-a58296171726'),
#             'IfcSpace_276965': rdflib.term.URIRef('https://lbd.example.com/space_5846f51d-5ade-4382-8ef9-a5829617172f'),
#             'IfcSpace_277227': rdflib.term.URIRef('https://lbd.example.com/space_5846f51d-5ade-4382-8ef9-a5829617169a'),
#             'IfcSpace_27741': rdflib.term.URIRef('https://lbd.example.com/space_c54f5ba5-100f-48cb-be39-360f87f64620'),
#             'IfcSpace_277411': rdflib.term.URIRef('https://lbd.example.com/space_5846f51d-5ade-4382-8ef9-a582961716b4'),
#             'IfcSpace_277595': rdflib.term.URIRef('https://lbd.example.com/space_5846f51d-5ade-4382-8ef9-a582961716bd'),
#             'IfcSpace_27852': rdflib.term.URIRef('https://lbd.example.com/space_c54f5ba5-100f-48cb-be39-360f87f64618'),
#             'IfcSpace_278712': rdflib.term.URIRef('https://lbd.example.com/space_5846f51d-5ade-4382-8ef9-a582961716a6'),
#             'IfcSpace_280384': rdflib.term.URIRef('https://lbd.example.com/space_5846f51d-5ade-4382-8ef9-a58296171117'),
#             'IfcSpace_280543': rdflib.term.URIRef('https://lbd.example.com/space_5846f51d-5ade-4382-8ef9-a5829617112b'),
#             'IfcSpace_280641': rdflib.term.URIRef('https://lbd.example.com/space_5846f51d-5ade-4382-8ef9-a582961710dd'),
#             'IfcSpace_280827': rdflib.term.URIRef('https://lbd.example.com/space_5846f51d-5ade-4382-8ef9-a5829617101e'),
#             'IfcSpace_280944': rdflib.term.URIRef('https://lbd.example.com/space_5846f51d-5ade-4382-8ef9-a58296171002'),
#             'IfcSpace_281192': rdflib.term.URIRef('https://lbd.example.com/space_5846f51d-5ade-4382-8ef9-a58296171036'),
#             'IfcSpace_282315': rdflib.term.URIRef('https://lbd.example.com/space_5846f51d-5ade-4382-8ef9-a582961713e0'),
#             'IfcSpace_282529': rdflib.term.URIRef('https://lbd.example.com/space_5846f51d-5ade-4382-8ef9-a58296171312'),
#             'IfcSpace_282658': rdflib.term.URIRef('https://lbd.example.com/space_5846f51d-5ade-4382-8ef9-a5829617131b'),
#             'IfcSpace_282771': rdflib.term.URIRef('https://lbd.example.com/space_5846f51d-5ade-4382-8ef9-a58296171296'),
#             'IfcSpace_283036': rdflib.term.URIRef('https://lbd.example.com/space_5846f51d-5ade-4382-8ef9-a58296171240'),
#             'IfcSpace_283378': rdflib.term.URIRef('https://lbd.example.com/space_5846f51d-5ade-4382-8ef9-a58296171279'),
#             'IfcSpace_285721': rdflib.term.URIRef('https://lbd.example.com/space_06546b8f-071b-4473-a594-8c752b39c0db'),
#             'IfcSpace_286020': rdflib.term.URIRef('https://lbd.example.com/space_06546b8f-071b-4473-a594-8c752b39c37c'),
#             'IfcSpace_288176': rdflib.term.URIRef('https://lbd.example.com/space_06546b8f-071b-4473-a594-8c752b39c368'),
#             'IfcSpace_289365': rdflib.term.URIRef('https://lbd.example.com/space_06546b8f-071b-4473-a594-8c752b39c298'),
#             'IfcSpace_290517': rdflib.term.URIRef('https://lbd.example.com/space_06546b8f-071b-4473-a594-8c752b39c289'),
#             'IfcSpace_29057': rdflib.term.URIRef('https://lbd.example.com/space_c54f5ba5-100f-48cb-be39-360f87f64603'),
#             'IfcSpace_291597': rdflib.term.URIRef('https://lbd.example.com/space_06546b8f-071b-4473-a594-8c752b39c2ba'),
#             'IfcSpace_291747': rdflib.term.URIRef('https://lbd.example.com/space_06546b8f-071b-4473-a594-8c752b39c2a8'),
#             'IfcSpace_291873': rdflib.term.URIRef('https://lbd.example.com/space_b65274cd-f25a-4b53-9dae-d8d4a7f72005'),
#             'IfcSpace_292006': rdflib.term.URIRef('https://lbd.example.com/space_8b964061-ac19-494e-9cd0-ff2011583380'),
#             'IfcSpace_292170': rdflib.term.URIRef('https://lbd.example.com/space_b70fa7b7-6a10-4908-965e-520868fa63a8'),
#             'IfcSpace_29289': rdflib.term.URIRef('https://lbd.example.com/space_e64de408-942a-4ad6-a99a-b228a200a3f1'),
#             'IfcSpace_292963': rdflib.term.URIRef('https://lbd.example.com/space_69dc9694-5510-4099-bd4e-f82dc52c87eb'),
#             'IfcSpace_293056': rdflib.term.URIRef('https://lbd.example.com/space_7dc52166-ebda-4197-980b-a49690bb2936'),
#             'IfcSpace_293158': rdflib.term.URIRef('https://lbd.example.com/space_11d01df8-8a65-4de1-9db8-f4240e4ab21c'),
#             'IfcSpace_293376': rdflib.term.URIRef('https://lbd.example.com/space_11d01df8-8a65-4de1-9db8-f4240e4ab210'),
#             'IfcSpace_293471': rdflib.term.URIRef('https://lbd.example.com/space_15e97062-597f-4cec-b286-da186c1189b8'),
#             'IfcSpace_293563': rdflib.term.URIRef('https://lbd.example.com/space_15e97062-597f-4cec-b286-da186c11898b'),
#             'IfcSpace_294376': rdflib.term.URIRef('https://lbd.example.com/space_0566554c-b63c-4dc4-a28e-6b6484b49baf'),
#             'IfcSpace_294481': rdflib.term.URIRef('https://lbd.example.com/space_b66d1b5c-fd06-49f7-a7e7-f2f76abbdf38'),
#             'IfcSpace_294582': rdflib.term.URIRef('https://lbd.example.com/space_9031c9fc-6dbe-42fb-b0f2-29550c2d551e'),
#             'IfcSpace_294742': rdflib.term.URIRef('https://lbd.example.com/space_9127efbb-9c4a-429e-a721-53ad6e40a3d1'),
#             'IfcSpace_294845': rdflib.term.URIRef('https://lbd.example.com/space_4fddceba-882d-425e-bbbb-653d4dc02fe2'),
#             'IfcSpace_295095': rdflib.term.URIRef('https://lbd.example.com/space_4fddceba-882d-425e-bbbb-653d4dc02fd9'),
#             'IfcSpace_295310': rdflib.term.URIRef('https://lbd.example.com/space_01519f39-acb7-4122-b231-2e6fff179c78'),
#             'IfcSpace_295406': rdflib.term.URIRef('https://lbd.example.com/space_9cc714eb-b4e1-4fd3-92f9-ef9913c5a9cb'),
#             'IfcSpace_295645': rdflib.term.URIRef('https://lbd.example.com/space_9cc714eb-b4e1-4fd3-92f9-ef9913c5a9e9'),
#             'IfcSpace_296375': rdflib.term.URIRef('https://lbd.example.com/space_9cc714eb-b4e1-4fd3-92f9-ef9913c5a99f'),
#             'IfcSpace_296544': rdflib.term.URIRef('https://lbd.example.com/space_718002f8-a031-464f-883f-ccd4a088f8eb'),
#             'IfcSpace_296674': rdflib.term.URIRef('https://lbd.example.com/space_718002f8-a031-464f-883f-ccd4a088f8f3'),
#             'IfcSpace_297519': rdflib.term.URIRef('https://lbd.example.com/space_718002f8-a031-464f-883f-ccd4a088f8fb'),
#             'IfcSpace_297631': rdflib.term.URIRef('https://lbd.example.com/space_718002f8-a031-464f-883f-ccd4a088f8da'),
#             'IfcSpace_297723': rdflib.term.URIRef('https://lbd.example.com/space_fd9027af-4475-43cf-9d0f-69dbe61035d6'),
#             'IfcSpace_297815': rdflib.term.URIRef('https://lbd.example.com/space_fd9027af-4475-43cf-9d0f-69dbe61035d0'),
#             'IfcSpace_297906': rdflib.term.URIRef('https://lbd.example.com/space_fd9027af-4475-43cf-9d0f-69dbe61035dc'),
#             'IfcSpace_297999': rdflib.term.URIRef('https://lbd.example.com/space_fd9027af-4475-43cf-9d0f-69dbe61035de'),
#             'IfcSpace_298094': rdflib.term.URIRef('https://lbd.example.com/space_fd9027af-4475-43cf-9d0f-69dbe61035da'),
#             'IfcSpace_298186': rdflib.term.URIRef('https://lbd.example.com/space_fd9027af-4475-43cf-9d0f-69dbe61035c4'),
#             'IfcSpace_298364': rdflib.term.URIRef('https://lbd.example.com/space_a0e0e336-35bf-4235-bbd0-535395bf2123'),
#             'IfcSpace_298553': rdflib.term.URIRef('https://lbd.example.com/space_bf49bcf6-5312-4ddd-9b16-bddb50827ff1'),
#             'IfcSpace_298650': rdflib.term.URIRef('https://lbd.example.com/space_442a4c72-dde9-4519-8844-c8f50eba3338'),
#             'IfcSpace_298743': rdflib.term.URIRef('https://lbd.example.com/space_442a4c72-dde9-4519-8844-c8f50eba3339'),
#             'IfcSpace_298835': rdflib.term.URIRef('https://lbd.example.com/space_442a4c72-dde9-4519-8844-c8f50eba333c'),
#             'IfcSpace_298946': rdflib.term.URIRef('https://lbd.example.com/space_442a4c72-dde9-4519-8844-c8f50eba333e'),
#             'IfcSpace_299040': rdflib.term.URIRef('https://lbd.example.com/space_442a4c72-dde9-4519-8844-c8f50eba3289'),
#             'IfcSpace_299132': rdflib.term.URIRef('https://lbd.example.com/space_442a4c72-dde9-4519-8844-c8f50eba328a'),
#             'IfcSpace_299225': rdflib.term.URIRef('https://lbd.example.com/space_442a4c72-dde9-4519-8844-c8f50eba328d'),
#             'IfcSpace_299339': rdflib.term.URIRef('https://lbd.example.com/space_442a4c72-dde9-4519-8844-c8f50eba328f'),
#             'IfcSpace_299433': rdflib.term.URIRef('https://lbd.example.com/space_442a4c72-dde9-4519-8844-c8f50eba32fd'),
#             'IfcSpace_299525': rdflib.term.URIRef('https://lbd.example.com/space_442a4c72-dde9-4519-8844-c8f50eba32fe'),
#             'IfcSpace_299615': rdflib.term.URIRef('https://lbd.example.com/space_442a4c72-dde9-4519-8844-c8f50eba32f1'),
#             'IfcSpace_299725': rdflib.term.URIRef('https://lbd.example.com/space_442a4c72-dde9-4519-8844-c8f50eba32f3'),
#             'IfcSpace_299819': rdflib.term.URIRef('https://lbd.example.com/space_442a4c72-dde9-4519-8844-c8f50eba324f'),
#             'IfcSpace_299910': rdflib.term.URIRef('https://lbd.example.com/space_442a4c72-dde9-4519-8844-c8f50eba3240'),
#             'IfcSpace_300001': rdflib.term.URIRef('https://lbd.example.com/space_442a4c72-dde9-4519-8844-c8f50eba3243'),
#             'IfcSpace_300114': rdflib.term.URIRef('https://lbd.example.com/space_442a4c72-dde9-4519-8844-c8f50eba3245'),
#             'IfcSpace_300299': rdflib.term.URIRef('https://lbd.example.com/space_685ccb9b-c085-4be3-a48d-7762d1c9fbc3'),
#             'IfcSpace_300519': rdflib.term.URIRef('https://lbd.example.com/space_685ccb9b-c085-4be3-a48d-7762d1c9fbc6'),
#             'IfcSpace_300617': rdflib.term.URIRef('https://lbd.example.com/space_685ccb9b-c085-4be3-a48d-7762d1c9fbbe'),
#             'IfcSpace_300837': rdflib.term.URIRef('https://lbd.example.com/space_685ccb9b-c085-4be3-a48d-7762d1c9fbb1'),
#             'IfcSpace_300933': rdflib.term.URIRef('https://lbd.example.com/space_685ccb9b-c085-4be3-a48d-7762d1c9fbab'),
#             'IfcSpace_301105': rdflib.term.URIRef('https://lbd.example.com/space_685ccb9b-c085-4be3-a48d-7762d1c9fb99'),
#             'IfcSpace_301312': rdflib.term.URIRef('https://lbd.example.com/space_685ccb9b-c085-4be3-a48d-7762d1c9fb9c'),
#             'IfcSpace_302138': rdflib.term.URIRef('https://lbd.example.com/space_685ccb9b-c085-4be3-a48d-7762d1c9fb7f'),
#             'IfcSpace_302820': rdflib.term.URIRef('https://lbd.example.com/space_685ccb9b-c085-4be3-a48d-7762d1c9fb71'),
#             'IfcSpace_302927': rdflib.term.URIRef('https://lbd.example.com/space_685ccb9b-c085-4be3-a48d-7762d1c9fb76'),
#             'IfcSpace_303034': rdflib.term.URIRef('https://lbd.example.com/space_86f303b3-7d15-4da3-9337-0065ab766389'),
#             'IfcSpace_303848': rdflib.term.URIRef('https://lbd.example.com/space_86f303b3-7d15-4da3-9337-0065ab76638e'),
#             'IfcSpace_304463': rdflib.term.URIRef('https://lbd.example.com/space_861a8d5c-6683-45e6-a3f2-3c6a08e33d22'),
#             'IfcSpace_304631': rdflib.term.URIRef('https://lbd.example.com/space_a49e0308-eee5-4e8a-bb32-a4f1d4b56f82'),
#             'IfcSpace_304814': rdflib.term.URIRef('https://lbd.example.com/space_a49e0308-eee5-4e8a-bb32-a4f1d4b56f83'),
#             'IfcSpace_304919': rdflib.term.URIRef('https://lbd.example.com/space_a49e0308-eee5-4e8a-bb32-a4f1d4b56f96'),
#             'IfcSpace_305028': rdflib.term.URIRef('https://lbd.example.com/space_a49e0308-eee5-4e8a-bb32-a4f1d4b56f97'),
#             'IfcSpace_305240': rdflib.term.URIRef('https://lbd.example.com/space_a49e0308-eee5-4e8a-bb32-a4f1d4b56fac'),
#             'IfcSpace_305331': rdflib.term.URIRef('https://lbd.example.com/space_a49e0308-eee5-4e8a-bb32-a4f1d4b56fae'),
#             'IfcSpace_305441': rdflib.term.URIRef('https://lbd.example.com/space_a49e0308-eee5-4e8a-bb32-a4f1d4b56faa'),
#             'IfcSpace_305548': rdflib.term.URIRef('https://lbd.example.com/space_a49e0308-eee5-4e8a-bb32-a4f1d4b56fab'),
#             'IfcSpace_305741': rdflib.term.URIRef('https://lbd.example.com/space_a49e0308-eee5-4e8a-bb32-a4f1d4b56fa0'),
#             'IfcSpace_30576': rdflib.term.URIRef('https://lbd.example.com/space_e64de408-942a-4ad6-a99a-b228a200a3ea'),
#             'IfcSpace_305831': rdflib.term.URIRef('https://lbd.example.com/space_a49e0308-eee5-4e8a-bb32-a4f1d4b56fa2'),
#             'IfcSpace_30684': rdflib.term.URIRef('https://lbd.example.com/space_e64de408-942a-4ad6-a99a-b228a200a3e2'),
#             'IfcSpace_30802': rdflib.term.URIRef('https://lbd.example.com/space_e64de408-942a-4ad6-a99a-b228a200a3d6'),
#             'IfcSpace_30996': rdflib.term.URIRef('https://lbd.example.com/space_e64de408-942a-4ad6-a99a-b228a200a3cf'),
#             'IfcSpace_31255': rdflib.term.URIRef('https://lbd.example.com/space_e64de408-942a-4ad6-a99a-b228a200a3c0'),
#             'IfcSpace_313108': rdflib.term.URIRef('https://lbd.example.com/space_a49e0308-eee5-4e8a-bb32-a4f1d4b56fce'),
#             'IfcSpace_313201': rdflib.term.URIRef('https://lbd.example.com/space_8e8c6c91-a38d-4f6e-a53c-1107859a2c56'),
#             'IfcSpace_313308': rdflib.term.URIRef('https://lbd.example.com/space_e79a4cec-3852-47b1-aaf5-8a4bc0af9947'),
#             'IfcSpace_313432': rdflib.term.URIRef('https://lbd.example.com/space_e79a4cec-3852-47b1-aaf5-8a4bc0af994d'),
#             'IfcSpace_313538': rdflib.term.URIRef('https://lbd.example.com/space_e79a4cec-3852-47b1-aaf5-8a4bc0af9eb4'),
#             'IfcSpace_313634': rdflib.term.URIRef('https://lbd.example.com/space_e79a4cec-3852-47b1-aaf5-8a4bc0af9ea2'),
#             'IfcSpace_313833': rdflib.term.URIRef('https://lbd.example.com/space_9f3b5fd9-f4ec-4f91-a985-4b6121aedb36'),
#             'IfcSpace_313942': rdflib.term.URIRef('https://lbd.example.com/space_34820ace-0784-4462-ada4-26851e1d487c'),
#             'IfcSpace_314036': rdflib.term.URIRef('https://lbd.example.com/space_5eb17f54-a360-4e72-8187-042ed0b95d05'),
#             'IfcSpace_314144': rdflib.term.URIRef('https://lbd.example.com/space_5eb17f54-a360-4e72-8187-042ed0b95d32'),
#             'IfcSpace_314247': rdflib.term.URIRef('https://lbd.example.com/space_5eb17f54-a360-4e72-8187-042ed0b95d20'),
#             'IfcSpace_314339': rdflib.term.URIRef('https://lbd.example.com/space_5eb17f54-a360-4e72-8187-042ed0b95d2c'),
#             'IfcSpace_314431': rdflib.term.URIRef('https://lbd.example.com/space_5eb17f54-a360-4e72-8187-042ed0b95dd8'),
#             'IfcSpace_314727': rdflib.term.URIRef('https://lbd.example.com/space_9f2d4c94-88cd-4f44-a1e2-3428bd162477'),
#             'IfcSpace_31499': rdflib.term.URIRef('https://lbd.example.com/space_e64de408-942a-4ad6-a99a-b228a200a334'),
#             'IfcSpace_315011': rdflib.term.URIRef('https://lbd.example.com/space_a626e183-7e7f-4543-ba01-e4a260409a7f'),
#             'IfcSpace_315114': rdflib.term.URIRef('https://lbd.example.com/space_433efa3e-0037-4716-9c23-e79779ff5bfc'),
#             'IfcSpace_315217': rdflib.term.URIRef('https://lbd.example.com/space_ee45769a-849a-4ca2-966f-26f2cd49667a'),
#             'IfcSpace_315311': rdflib.term.URIRef('https://lbd.example.com/space_67edf2aa-5d4d-46e4-978c-fac26644313f'),
#             'IfcSpace_315413': rdflib.term.URIRef('https://lbd.example.com/space_fea53240-44b1-4d04-8a3d-2627f4de4a78'),
#             'IfcSpace_315507': rdflib.term.URIRef('https://lbd.example.com/space_e501c21d-128f-45b1-afdf-13fae87c88e1'),
#             'IfcSpace_315599': rdflib.term.URIRef('https://lbd.example.com/space_41b5bb1e-1ed3-4729-bc5e-afa8ad4b3955'),
#             'IfcSpace_315782': rdflib.term.URIRef('https://lbd.example.com/space_e49c1865-8747-4760-ab26-60fff711d6d2'),
#             'IfcSpace_316007': rdflib.term.URIRef('https://lbd.example.com/space_78cbee30-53f5-49f4-b2df-2be1f7e115c9'),
#             'IfcSpace_31631': rdflib.term.URIRef('https://lbd.example.com/space_e64de408-942a-4ad6-a99a-b228a200a328'),
#             'IfcSpace_316412': rdflib.term.URIRef('https://lbd.example.com/space_e6e4d194-16d4-42d2-b118-cd61b2790495'),
#             'IfcSpace_31748': rdflib.term.URIRef('https://lbd.example.com/space_e64de408-942a-4ad6-a99a-b228a200a321'),
#             'IfcSpace_318257': rdflib.term.URIRef('https://lbd.example.com/space_f41afda6-739e-40b2-befb-33c2c349780f'),
#             'IfcSpace_318364': rdflib.term.URIRef('https://lbd.example.com/space_f41afda6-739e-40b2-befb-33c2c3497817'),
#             'IfcSpace_318662': rdflib.term.URIRef('https://lbd.example.com/space_f41afda6-739e-40b2-befb-33c2c349789f'),
#             'IfcSpace_318997': rdflib.term.URIRef('https://lbd.example.com/space_e0b0dcba-ab7e-4e18-975a-ca6e4c2c49dd'),
#             'IfcSpace_319118': rdflib.term.URIRef('https://lbd.example.com/space_dbb5bd1d-16af-4acb-b074-b2191558ee35'),
#             'IfcSpace_319453': rdflib.term.URIRef('https://lbd.example.com/space_dbb5bd1d-16af-4acb-b074-b2191558ef52'),
#             'IfcSpace_319697': rdflib.term.URIRef('https://lbd.example.com/space_18f4d50f-499b-4a55-83e6-13aee0063182'),
#             'IfcSpace_319977': rdflib.term.URIRef('https://lbd.example.com/space_38173db4-0652-448c-bc58-c9a3e5460589'),
#             'IfcSpace_320190': rdflib.term.URIRef('https://lbd.example.com/space_58ac3e08-e658-436a-a037-44861bffb031'),
#             'IfcSpace_320305': rdflib.term.URIRef('https://lbd.example.com/space_41ccd8e1-f4bb-4b64-b006-f1a8e40257cf'),
#             'IfcSpace_320801': rdflib.term.URIRef('https://lbd.example.com/space_2e667ebf-423c-41f5-9d41-f17bd8936292'),
#             'IfcSpace_321181': rdflib.term.URIRef('https://lbd.example.com/space_2e667ebf-423c-41f5-9d41-f17bd89362e3'),
#             'IfcSpace_321295': rdflib.term.URIRef('https://lbd.example.com/space_2e667ebf-423c-41f5-9d41-f17bd89362da'),
#             'IfcSpace_321756': rdflib.term.URIRef('https://lbd.example.com/space_2e667ebf-423c-41f5-9d41-f17bd8936225'),
#             'IfcSpace_322249': rdflib.term.URIRef('https://lbd.example.com/space_2e667ebf-423c-41f5-9d41-f17bd8936223'),
#             'IfcSpace_322542': rdflib.term.URIRef('https://lbd.example.com/space_2e667ebf-423c-41f5-9d41-f17bd8936221'),
#             'IfcSpace_322831': rdflib.term.URIRef('https://lbd.example.com/space_2e667ebf-423c-41f5-9d41-f17bd893622f'),
#             'IfcSpace_323140': rdflib.term.URIRef('https://lbd.example.com/space_2e667ebf-423c-41f5-9d41-f17bd893622d'),
#             'IfcSpace_323431': rdflib.term.URIRef('https://lbd.example.com/space_2e667ebf-423c-41f5-9d41-f17bd893622b'),
#             'IfcSpace_323685': rdflib.term.URIRef('https://lbd.example.com/space_2e667ebf-423c-41f5-9d41-f17bd8936229'),
#             'IfcSpace_324119': rdflib.term.URIRef('https://lbd.example.com/space_2e667ebf-423c-41f5-9d41-f17bd893620b'),
#             'IfcSpace_324452': rdflib.term.URIRef('https://lbd.example.com/space_2e667ebf-423c-41f5-9d41-f17bd8936208'),
#             'IfcSpace_324734': rdflib.term.URIRef('https://lbd.example.com/space_2e667ebf-423c-41f5-9d41-f17bd8936215'),
#             'IfcSpace_325015': rdflib.term.URIRef('https://lbd.example.com/space_2e667ebf-423c-41f5-9d41-f17bd8936212'),
# ...
#             'IfcSpace_546638': rdflib.term.URIRef('https://lbd.example.com/space_33626c69-7135-4ef0-aa50-3b468a812bdf'),
#             'IfcSpace_546917': rdflib.term.URIRef('https://lbd.example.com/space_33626c69-7135-4ef0-aa50-3b468a811471'),
#             'IfcSpace_547221': rdflib.term.URIRef('https://lbd.example.com/space_33626c69-7135-4ef0-aa50-3b468a8114ce'),
#             'IfcSpace_547319': rdflib.term.URIRef('https://lbd.example.com/space_33626c69-7135-4ef0-aa50-3b468a811049'),
#             'IfcSpace_547404': rdflib.term.URIRef('https://lbd.example.com/space_33626c69-7135-4ef0-aa50-3b468a8110f3'),
#             'IfcSpace_547461': rdflib.term.URIRef('https://lbd.example.com/space_33626c69-7135-4ef0-aa50-3b468a811164'),
#             'IfcSpace_547522': rdflib.term.URIRef('https://lbd.example.com/space_d3138cd1-7f8d-49a4-be2e-8c4afc215281'),
#             'IfcSpace_547741': rdflib.term.URIRef('https://lbd.example.com/space_12009f61-a7ac-4445-90f9-5e89fec703f2'),
#             'IfcSpace_547995': rdflib.term.URIRef('https://lbd.example.com/space_12009f61-a7ac-4445-90f9-5e89fec703fd'),
#             'IfcSpace_548256': rdflib.term.URIRef('https://lbd.example.com/space_12009f61-a7ac-4445-90f9-5e89fec7045c'),
#             'IfcSpace_548509': rdflib.term.URIRef('https://lbd.example.com/space_12009f61-a7ac-4445-90f9-5e89fec704a7'),
#             'IfcSpace_548754': rdflib.term.URIRef('https://lbd.example.com/space_12009f61-a7ac-4445-90f9-5e89fec70535'),
#             'IfcSpace_548957': rdflib.term.URIRef('https://lbd.example.com/space_12009f61-a7ac-4445-90f9-5e89fec705be'),
#             'IfcSpace_549156': rdflib.term.URIRef('https://lbd.example.com/space_b6545ed5-4ad9-45f1-8b97-0a0874ba29a4'),
#             'IfcSpace_549382': rdflib.term.URIRef('https://lbd.example.com/space_b6545ed5-4ad9-45f1-8b97-0a0874ba29bd'),
#             'IfcSpace_549634': rdflib.term.URIRef('https://lbd.example.com/space_b6545ed5-4ad9-45f1-8b97-0a0874ba2934'),
#             'IfcSpace_549845': rdflib.term.URIRef('https://lbd.example.com/space_b6545ed5-4ad9-45f1-8b97-0a0874ba290d'),
#             'IfcSpace_549970': rdflib.term.URIRef('https://lbd.example.com/space_87a74515-7796-4cab-996a-65cac1741c06'),
#             'IfcSpace_550214': rdflib.term.URIRef('https://lbd.example.com/space_87a74515-7796-4cab-996a-65cac1741dfc'),
#             'IfcSpace_550465': rdflib.term.URIRef('https://lbd.example.com/space_87a74515-7796-4cab-996a-65cac1741deb'),
#             'IfcSpace_550716': rdflib.term.URIRef('https://lbd.example.com/space_87a74515-7796-4cab-996a-65cac1741d94'),
#             'IfcSpace_550974': rdflib.term.URIRef('https://lbd.example.com/space_87a74515-7796-4cab-996a-65cac1741d75'),
#             'IfcSpace_551232': rdflib.term.URIRef('https://lbd.example.com/space_87a74515-7796-4cab-996a-65cac1741d1f'),
#             'IfcSpace_551472': rdflib.term.URIRef('https://lbd.example.com/space_87a74515-7796-4cab-996a-65cac1741d0d'),
#             'IfcSpace_551590': rdflib.term.URIRef('https://lbd.example.com/space_87a74515-7796-4cab-996a-65cac1741ae5'),
#             'IfcSpace_554928': rdflib.term.URIRef('https://lbd.example.com/space_1c757b38-9c11-4138-ab2a-1edfd187abb1'),
#             'IfcSpace_556119': rdflib.term.URIRef('https://lbd.example.com/space_53364c95-e030-4f21-ae60-c5876df8855d'),
#             'IfcSpace_556279': rdflib.term.URIRef('https://lbd.example.com/space_9a2d747d-8135-4a8b-a46e-05ad7cc74c2d'),
#             'IfcSpace_556444': rdflib.term.URIRef('https://lbd.example.com/space_9a2d747d-8135-4a8b-a46e-05ad7cc74c31'),
#             'IfcSpace_556644': rdflib.term.URIRef('https://lbd.example.com/space_9a2d747d-8135-4a8b-a46e-05ad7cc74cc5'),
#             'IfcSpace_556884': rdflib.term.URIRef('https://lbd.example.com/space_9a2d747d-8135-4a8b-a46e-05ad7cc74ccb'),
#             'IfcSpace_557049': rdflib.term.URIRef('https://lbd.example.com/space_9a2d747d-8135-4a8b-a46e-05ad7cc74cd1'),
#             'IfcSpace_557214': rdflib.term.URIRef('https://lbd.example.com/space_9a2d747d-8135-4a8b-a46e-05ad7cc74ce7'),
#             'IfcSpace_557397': rdflib.term.URIRef('https://lbd.example.com/space_9a2d747d-8135-4a8b-a46e-05ad7cc74ced'),
#             'IfcSpace_557579': rdflib.term.URIRef('https://lbd.example.com/space_9a2d747d-8135-4a8b-a46e-05ad7cc74cf3'),
#             'IfcSpace_557698': rdflib.term.URIRef('https://lbd.example.com/space_9a2d747d-8135-4a8b-a46e-05ad7cc74cf9'),
#             'IfcSpace_557899': rdflib.term.URIRef('https://lbd.example.com/space_9a2d747d-8135-4a8b-a46e-05ad7cc74c8f'),
#             'IfcSpace_558175': rdflib.term.URIRef('https://lbd.example.com/space_9a2d747d-8135-4a8b-a46e-05ad7cc74959'),
#             'IfcSpace_558804': rdflib.term.URIRef('https://lbd.example.com/space_9a2d747d-8135-4a8b-a46e-05ad7cc74966'),
#             'IfcSpace_558963': rdflib.term.URIRef('https://lbd.example.com/space_9a2d747d-8135-4a8b-a46e-05ad7cc74963'),
#             'IfcSpace_559270': rdflib.term.URIRef('https://lbd.example.com/space_9a2d747d-8135-4a8b-a46e-05ad7cc74960'),
#             'IfcSpace_559447': rdflib.term.URIRef('https://lbd.example.com/space_9a2d747d-8135-4a8b-a46e-05ad7cc7496d'),
#             'IfcSpace_560174': rdflib.term.URIRef('https://lbd.example.com/space_9a2d747d-8135-4a8b-a46e-05ad7cc7483b'),
#             'IfcSpace_560342': rdflib.term.URIRef('https://lbd.example.com/space_9a2d747d-8135-4a8b-a46e-05ad7cc748a4'),
#             'IfcSpace_560528': rdflib.term.URIRef('https://lbd.example.com/space_9a2d747d-8135-4a8b-a46e-05ad7cc748b6'),
#             'IfcSpace_561173': rdflib.term.URIRef('https://lbd.example.com/space_9a2d747d-8135-4a8b-a46e-05ad7cc748bb'),
#             'IfcSpace_561331': rdflib.term.URIRef('https://lbd.example.com/space_9a2d747d-8135-4a8b-a46e-05ad7cc74b5e'),
#             'IfcSpace_561960': rdflib.term.URIRef('https://lbd.example.com/space_9a2d747d-8135-4a8b-a46e-05ad7cc74b63'),
#             'IfcSpace_562118': rdflib.term.URIRef('https://lbd.example.com/space_9a2d747d-8135-4a8b-a46e-05ad7cc74b68'),
#             'IfcSpace_562986': rdflib.term.URIRef('https://lbd.example.com/space_9a2d747d-8135-4a8b-a46e-05ad7cc74b7d'),
#             'IfcSpace_563154': rdflib.term.URIRef('https://lbd.example.com/space_9a2d747d-8135-4a8b-a46e-05ad7cc74b02'),
#             'IfcSpace_563324': rdflib.term.URIRef('https://lbd.example.com/space_9a2d747d-8135-4a8b-a46e-05ad7cc74b17'),
#             'IfcSpace_563767': rdflib.term.URIRef('https://lbd.example.com/space_9a2d747d-8135-4a8b-a46e-05ad7cc74b1c'),
#             'IfcSpace_564070': rdflib.term.URIRef('https://lbd.example.com/space_9a2d747d-8135-4a8b-a46e-05ad7cc74b21'),
#             'IfcSpace_564231': rdflib.term.URIRef('https://lbd.example.com/space_9a2d747d-8135-4a8b-a46e-05ad7cc74b36'),
#             'IfcSpace_564344': rdflib.term.URIRef('https://lbd.example.com/space_261eb933-0526-4856-8326-766fddc77432'),
#             'IfcSpace_56443': rdflib.term.URIRef('https://lbd.example.com/space_ba0b3a29-6dae-4f1e-b215-3b6a0d38a3a4'),
#             'IfcSpace_56552': rdflib.term.URIRef('https://lbd.example.com/space_ba0b3a29-6dae-4f1e-b215-3b6a0d38a3f1'),
#             'IfcSpace_57295': rdflib.term.URIRef('https://lbd.example.com/space_ba0b3a29-6dae-4f1e-b215-3b6a0d38a304'),
#             'IfcSpace_57415': rdflib.term.URIRef('https://lbd.example.com/space_ba0b3a29-6dae-4f1e-b215-3b6a0d38a36c'),
#             'IfcSpace_58133': rdflib.term.URIRef('https://lbd.example.com/space_ba0b3a29-6dae-4f1e-b215-3b6a0d38a376'),
#             'IfcSpace_582749': rdflib.term.URIRef('https://lbd.example.com/space_a8530056-6e5b-49bd-afe9-b8632d71a8f1'),
#             'IfcSpace_584503': rdflib.term.URIRef('https://lbd.example.com/space_874157c1-3c08-48b4-a81e-0e314bf5d510'),
#             'IfcSpace_585922': rdflib.term.URIRef('https://lbd.example.com/space_4fa8f515-74cb-49e2-bd49-790d212fe590'),
#             'IfcSpace_586982': rdflib.term.URIRef('https://lbd.example.com/space_4fa8f515-74cb-49e2-bd49-790d212fe5ff'),
#             'IfcSpace_587081': rdflib.term.URIRef('https://lbd.example.com/space_398fea39-8e6c-4a06-a8ab-ce69417bb924'),
#             'IfcSpace_587224': rdflib.term.URIRef('https://lbd.example.com/space_398fea39-8e6c-4a06-a8ab-ce69417bb949'),
#             'IfcSpace_587415': rdflib.term.URIRef('https://lbd.example.com/space_398fea39-8e6c-4a06-a8ab-ce69417bb94c'),
#             'IfcSpace_587633': rdflib.term.URIRef('https://lbd.example.com/space_398fea39-8e6c-4a06-a8ab-ce69417bb94f'),
#             'IfcSpace_587887': rdflib.term.URIRef('https://lbd.example.com/space_398fea39-8e6c-4a06-a8ab-ce69417bbab2'),
#             'IfcSpace_588124': rdflib.term.URIRef('https://lbd.example.com/space_7002237a-34b9-4e4b-89fc-1b805d7a6b71'),
#             'IfcSpace_588326': rdflib.term.URIRef('https://lbd.example.com/space_7002237a-34b9-4e4b-89fc-1b805d7a6b6b'),
#             'IfcSpace_591360': rdflib.term.URIRef('https://lbd.example.com/space_7002237a-34b9-4e4b-89fc-1b805d7a6b66'),
#             'IfcSpace_592015': rdflib.term.URIRef('https://lbd.example.com/space_7002237a-34b9-4e4b-89fc-1b805d7a6b65'),
#             'IfcSpace_592627': rdflib.term.URIRef('https://lbd.example.com/space_7002237a-34b9-4e4b-89fc-1b805d7a6b60'),
#             'IfcSpace_592724': rdflib.term.URIRef('https://lbd.example.com/space_b7086454-0d16-4efc-add5-34b41ddec61a'),
#             'IfcSpace_592829': rdflib.term.URIRef('https://lbd.example.com/space_b7086454-0d16-4efc-add5-34b41ddec644'),
#             'IfcSpace_592928': rdflib.term.URIRef('https://lbd.example.com/space_b7086454-0d16-4efc-add5-34b41ddef97b'),
#             'IfcSpace_593022': rdflib.term.URIRef('https://lbd.example.com/space_2a7d7865-d60d-45a4-acd1-365f5ec2dc5e'),
#             'IfcSpace_593114': rdflib.term.URIRef('https://lbd.example.com/space_2a7d7865-d60d-45a4-acd1-365f5ec2ddc0'),
#             'IfcSpace_593206': rdflib.term.URIRef('https://lbd.example.com/space_2a7d7865-d60d-45a4-acd1-365f5ec2dd69'),
#             'IfcSpace_593992': rdflib.term.URIRef('https://lbd.example.com/space_6b146bc9-cfdd-4bd6-bc9c-516540e8cf27'),
#             'IfcSpace_596508': rdflib.term.URIRef('https://lbd.example.com/space_ec3d6500-b37d-4aa4-a892-1c1368c1d3d2'),
#             'IfcSpace_5968': rdflib.term.URIRef('https://lbd.example.com/space_f90bef97-ba5a-4f16-a512-56b7145e3343'),
#             'IfcSpace_599522': rdflib.term.URIRef('https://lbd.example.com/space_ec3d6500-b37d-4aa4-a892-1c1368c1d3de'),
#             'IfcSpace_60003': rdflib.term.URIRef('https://lbd.example.com/space_ba0b3a29-6dae-4f1e-b215-3b6a0d38a0b7'),
#             'IfcSpace_600217': rdflib.term.URIRef('https://lbd.example.com/space_b8640af7-7c15-4530-b42b-d0758223b407'),
#             'IfcSpace_600318': rdflib.term.URIRef('https://lbd.example.com/space_9aca2c16-7149-45b4-8749-1e77828bd433'),
#             'IfcSpace_600611': rdflib.term.URIRef('https://lbd.example.com/space_f64ac26c-f745-446b-9f70-360fdaecaf49'),
#             'IfcSpace_600858': rdflib.term.URIRef('https://lbd.example.com/space_f64ac26c-f745-446b-9f70-360fdaecaf46'),
#             'IfcSpace_600989': rdflib.term.URIRef('https://lbd.example.com/space_216f7418-dd1c-4c48-93d7-cd1d8b4d56ca'),
#             'IfcSpace_60453': rdflib.term.URIRef('https://lbd.example.com/space_ba0b3a29-6dae-4f1e-b215-3b6a0d38a0b8'),
#             'IfcSpace_60611': rdflib.term.URIRef('https://lbd.example.com/space_ba0b3a29-6dae-4f1e-b215-3b6a0d38a0d7'),
#             'IfcSpace_60923': rdflib.term.URIRef('https://lbd.example.com/space_ea00af63-0427-4f7a-ac26-9922f5123fb2'),
#             'IfcSpace_61185': rdflib.term.URIRef('https://lbd.example.com/space_e6b4c69f-169e-4263-80b4-4d04d1c13c0a'),
#             'IfcSpace_61406': rdflib.term.URIRef('https://lbd.example.com/space_e6b4c69f-169e-4263-80b4-4d04d1c13c05'),
#             'IfcSpace_61520': rdflib.term.URIRef('https://lbd.example.com/space_e6b4c69f-169e-4263-80b4-4d04d1c13c3c'),
#             'IfcSpace_6729': rdflib.term.URIRef('https://lbd.example.com/space_f90bef97-ba5a-4f16-a512-56b7145e334a'),
#             'IfcSpace_67518': rdflib.term.URIRef('https://lbd.example.com/space_e6b4c69f-169e-4263-80b4-4d04d1c13c22'),
#             'IfcSpace_6857': rdflib.term.URIRef('https://lbd.example.com/space_f90bef97-ba5a-4f16-a512-56b7145e3350'),
#             'IfcSpace_70041': rdflib.term.URIRef('https://lbd.example.com/space_e6b4c69f-169e-4263-80b4-4d04d1c13fde'),
#             'IfcSpace_70241': rdflib.term.URIRef('https://lbd.example.com/space_58076601-4cf1-4985-83bf-d6cc85034164'),
#             'IfcSpace_7041': rdflib.term.URIRef('https://lbd.example.com/space_f90bef97-ba5a-4f16-a512-56b7145e335f'),
#             'IfcSpace_72349': rdflib.term.URIRef('https://lbd.example.com/space_58076601-4cf1-4985-83bf-d6cc8503412e'),
#             'IfcSpace_7265': rdflib.term.URIRef('https://lbd.example.com/space_f90bef97-ba5a-4f16-a512-56b7145e337c'),
#             'IfcSpace_73105': rdflib.term.URIRef('https://lbd.example.com/space_58076601-4cf1-4985-83bf-d6cc8503413f'),
#             'IfcSpace_73199': rdflib.term.URIRef('https://lbd.example.com/space_58076601-4cf1-4985-83bf-d6cc85034136'),
#             'IfcSpace_73291': rdflib.term.URIRef('https://lbd.example.com/space_58076601-4cf1-4985-83bf-d6cc85034102'),
#             'IfcSpace_73393': rdflib.term.URIRef('https://lbd.example.com/space_e504a365-2262-4504-b44e-b9af56af97f8'),
#             'IfcSpace_73485': rdflib.term.URIRef('https://lbd.example.com/space_e504a365-2262-4504-b44e-b9af56af97f0'),
#             'IfcSpace_73730': rdflib.term.URIRef('https://lbd.example.com/space_5b1507b1-de8c-43ec-b654-412ced043b0a'),
#             'IfcSpace_73991': rdflib.term.URIRef('https://lbd.example.com/space_97c21ebe-257e-49d7-8057-58393195ee46'),
#             'IfcSpace_74163': rdflib.term.URIRef('https://lbd.example.com/space_97c21ebe-257e-49d7-8057-58393195ee7f'),
#             'IfcSpace_74424': rdflib.term.URIRef('https://lbd.example.com/space_97c21ebe-257e-49d7-8057-58393195ee78'),
#             'IfcSpace_74706': rdflib.term.URIRef('https://lbd.example.com/space_97c21ebe-257e-49d7-8057-58393195ee64'),
#             'IfcSpace_79559': rdflib.term.URIRef('https://lbd.example.com/space_97c21ebe-257e-49d7-8057-58393195ee1a'),
#             'IfcSpace_82060': rdflib.term.URIRef('https://lbd.example.com/space_df7623d4-2393-46f5-ad58-cefa15909695'),
#             'IfcSpace_85635': rdflib.term.URIRef('https://lbd.example.com/space_df7623d4-2393-46f5-ad58-cefa159096fd'),
#             'IfcSpace_9262': rdflib.term.URIRef('https://lbd.example.com/space_f90bef97-ba5a-4f16-a512-56b7145e308a')},
#  'storeys': {'IfcBuildingStorey_127': rdflib.term.URIRef('https://lbd.example.com/storey_28cb49f1-9b69-4870-aca3-d3f39d77ca99'),
#              'IfcBuildingStorey_133': rdflib.term.URIRef('https://lbd.example.com/storey_28cb49f1-9b69-4870-aca3-d3f39d7de40e'),
#              'IfcBuildingStorey_139': rdflib.term.URIRef('https://lbd.example.com/storey_28cb49f1-9b69-4870-aca3-d3f39d72d449'),
#              'IfcBuildingStorey_145': rdflib.term.URIRef('https://lbd.example.com/storey_28cb49f1-9b69-4870-aca3-d3f39d72d424'),
#              'IfcBuildingStorey_151': rdflib.term.URIRef('https://lbd.example.com/storey_28cb49f1-9b69-4870-aca3-d3f39d7581a2'),
#              'IfcBuildingStorey_157': rdflib.term.URIRef('https://lbd.example.com/storey_28cb49f1-9b69-4870-aca3-d3f39d758223'),
#              'IfcBuildingStorey_163': rdflib.term.URIRef('https://lbd.example.com/storey_28cb49f1-9b69-4870-aca3-d3f39d72d37f'),
#              'IfcBuildingStorey_169': rdflib.term.URIRef('https://lbd.example.com/storey_28cb49f1-9b69-4870-aca3-d3f39d72d36b'),
#              'IfcBuildingStorey_175': rdflib.term.URIRef('https://lbd.example.com/storey_28cb49f1-9b69-4870-aca3-d3f39d72d484'),
#              'IfcBuildingStorey_181': rdflib.term.URIRef('https://lbd.example.com/storey_28cb49f1-9b69-4870-aca3-d3f39d72d4c0'),
#              'IfcBuildingStorey_187': rdflib.term.URIRef('https://lbd.example.com/storey_28cb49f1-9b69-4870-aca3-d3f39d72d417'),
#              'IfcBuildingStorey_193': rdflib.term.URIRef('https://lbd.example.com/storey_28cb49f1-9b69-4870-aca3-d3f39d30d6fc')}}

# %%
g = Graph()
g.parse(ttl_ark, format="turtle")

BOT = Namespace("https://w3id.org/bot#")
PROPS = Namespace("http://lbd.arch.rwth-aachen.de/props#") 

storeys = g.subjects(RDF.type, BOT.Storey)

storey_props = {}

for storey in storeys:
    storey_props[str(storey)] = {
        str(p): str(o)
        for p, o in g.predicate_objects(storey)
        if str(p).startswith(str(PROPS))
    }

# %%
from pprint import pprint
print(f'{len(storey_props)} storeys with properties found:')
pprint(storey_props)
# Out:
# 12 storeys with properties found:
# {'https://lbd.example.com/storey_28cb49f1-9b69-4870-aca3-d3f39d30d6fc': {'http://lbd.arch.rwth-aachen.de/props#elevationIfcBuildingStorey_attribute_simple': '58100.0000000035',
#                                                                          'http://lbd.arch.rwth-aachen.de/props#globalIdIfcRoot_attribute_simple': '0eoqdncsb8SAoZq$ETCDRy',
#                                                                          'http://lbd.arch.rwth-aachen.de/props#longNameIfcSpatialStructureElement_attribute_simple': 'IV-Kammio'},
#  'https://lbd.example.com/storey_28cb49f1-9b69-4870-aca3-d3f39d72d36b': {'http://lbd.arch.rwth-aachen.de/props#elevationIfcBuildingStorey_attribute_simple': '41100.0000000061',
#                                                                          'http://lbd.arch.rwth-aachen.de/props#globalIdIfcRoot_attribute_simple': '0eoqdncsb8SAoZq$ETSjDh',
#                                                                          'http://lbd.arch.rwth-aachen.de/props#longNameIfcSpatialStructureElement_attribute_simple': '4.kerros'},
#  'https://lbd.example.com/storey_28cb49f1-9b69-4870-aca3-d3f39d72d37f': {'http://lbd.arch.rwth-aachen.de/props#elevationIfcBuildingStorey_attribute_simple': '36900.0000000061',
#                                                                          'http://lbd.arch.rwth-aachen.de/props#globalIdIfcRoot_attribute_simple': '0eoqdncsb8SAoZq$ETSjD$',
#                                                                          'http://lbd.arch.rwth-aachen.de/props#longNameIfcSpatialStructureElement_attribute_simple': '3.kerros'},
#  'https://lbd.example.com/storey_28cb49f1-9b69-4870-aca3-d3f39d72d417': {'http://lbd.arch.rwth-aachen.de/props#elevationIfcBuildingStorey_attribute_simple': '53700.0000000061',
#                                                                          'http://lbd.arch.rwth-aachen.de/props#globalIdIfcRoot_attribute_simple': '0eoqdncsb8SAoZq$ETSjGN',
#                                                                          'http://lbd.arch.rwth-aachen.de/props#longNameIfcSpatialStructureElement_attribute_simple': '7.kerros'},
#  'https://lbd.example.com/storey_28cb49f1-9b69-4870-aca3-d3f39d72d424': {'http://lbd.arch.rwth-aachen.de/props#elevationIfcBuildingStorey_attribute_simple': '23700.',
#                                                                          'http://lbd.arch.rwth-aachen.de/props#globalIdIfcRoot_attribute_simple': '0eoqdncsb8SAoZq$ETSjGa',
#                                                                          'http://lbd.arch.rwth-aachen.de/props#longNameIfcSpatialStructureElement_attribute_simple': '0.kerros'},
#  'https://lbd.example.com/storey_28cb49f1-9b69-4870-aca3-d3f39d72d449': {'http://lbd.arch.rwth-aachen.de/props#elevationIfcBuildingStorey_attribute_simple': '19899.9999999986',
#                                                                          'http://lbd.arch.rwth-aachen.de/props#globalIdIfcRoot_attribute_simple': '0eoqdncsb8SAoZq$ETSjH9',
#                                                                          'http://lbd.arch.rwth-aachen.de/props#longNameIfcSpatialStructureElement_attribute_simple': 'K.kerros'},
#  'https://lbd.example.com/storey_28cb49f1-9b69-4870-aca3-d3f39d72d484': {'http://lbd.arch.rwth-aachen.de/props#elevationIfcBuildingStorey_attribute_simple': '45300.0000000061',
#                                                                          'http://lbd.arch.rwth-aachen.de/props#globalIdIfcRoot_attribute_simple': '0eoqdncsb8SAoZq$ETSjI4',
#                                                                          'http://lbd.arch.rwth-aachen.de/props#longNameIfcSpatialStructureElement_attribute_simple': '5.kerros'},
#  'https://lbd.example.com/storey_28cb49f1-9b69-4870-aca3-d3f39d72d4c0': {'http://lbd.arch.rwth-aachen.de/props#elevationIfcBuildingStorey_attribute_simple': '49500.0000000061',
#                                                                          'http://lbd.arch.rwth-aachen.de/props#globalIdIfcRoot_attribute_simple': '0eoqdncsb8SAoZq$ETSjJ0',
#                                                                          'http://lbd.arch.rwth-aachen.de/props#longNameIfcSpatialStructureElement_attribute_simple': '6.kerros'},
#  'https://lbd.example.com/storey_28cb49f1-9b69-4870-aca3-d3f39d7581a2': {'http://lbd.arch.rwth-aachen.de/props#elevationIfcBuildingStorey_attribute_simple': '27800.',
#                                                                          'http://lbd.arch.rwth-aachen.de/props#globalIdIfcRoot_attribute_simple': '0eoqdncsb8SAoZq$ETTO6Y',
#                                                                          'http://lbd.arch.rwth-aachen.de/props#longNameIfcSpatialStructureElement_attribute_simple': '1.kerros'},
#  'https://lbd.example.com/storey_28cb49f1-9b69-4870-aca3-d3f39d758223': {'http://lbd.arch.rwth-aachen.de/props#elevationIfcBuildingStorey_attribute_simple': '32700.0000000061',
#                                                                          'http://lbd.arch.rwth-aachen.de/props#globalIdIfcRoot_attribute_simple': '0eoqdncsb8SAoZq$ETTO8Z',
#                                                                          'http://lbd.arch.rwth-aachen.de/props#longNameIfcSpatialStructureElement_attribute_simple': '2.kerros'},
#  'https://lbd.example.com/storey_28cb49f1-9b69-4870-aca3-d3f39d77ca99': {'http://lbd.arch.rwth-aachen.de/props#elevationIfcBuildingStorey_attribute_simple': '0.',
#                                                                          'http://lbd.arch.rwth-aachen.de/props#globalIdIfcRoot_attribute_simple': '0eoqdncsb8SAoZq$ETTygP',
#                                                                          'http://lbd.arch.rwth-aachen.de/props#longNameIfcSpatialStructureElement_attribute_simple': 'Merenpinta'},
#  'https://lbd.example.com/storey_28cb49f1-9b69-4870-aca3-d3f39d7de40e': {'http://lbd.arch.rwth-aachen.de/props#elevationIfcBuildingStorey_attribute_simple': '15899.9999999986',
#                                                                          'http://lbd.arch.rwth-aachen.de/props#globalIdIfcRoot_attribute_simple': '0eoqdncsb8SAoZq$ETVUGE',
#                                                                          'http://lbd.arch.rwth-aachen.de/props#longNameIfcSpatialStructureElement_attribute_simple': 'R.kerros'}}

# %%
arch_ifc = ifcopenshell.open("C:/Users/yanpe/OneDrive - Metropolia Ammattikorkeakoulu Oy/Research/MD2MV/data/IFC/01ARK/ARK_MET.ifc")
arch_site = arch_ifc.by_type("IfcSite")[0]
arch_site.get_info()
# Out:
# {'id': 23678881,
#  'type': 'IfcSite',
#  'GlobalId': '0eoqdncsb8SAoZq$DYYdzd',
#  'OwnerHistory': #41=IfcOwnerHistory(#38,#5,$,.NOCHANGE.,$,$,$,0),
#  'Name': 'Default',
#  'Description': None,
#  'ObjectType': '',
#  'ObjectPlacement': #23678880=IfcLocalPlacement($,#23678879),
#  'Representation': None,
#  'LongName': None,
#  'CompositionType': 'ELEMENT',
#  'RefLatitude': (60, 13, 29, 994506),
#  'RefLongitude': (25, 4, 32, 885),
#  'RefElevation': 0.0,
#  'LandTitleNumber': None,
#  'SiteAddress': None}

# %%
arch_ifc.by_id(127)
# Out:
# #127=IfcBuildingStorey('0eoqdncsb8SAoZq$ETTygP',#41,'Merenpinta',$,$,#125,$,'Merenpinta',.ELEMENT.,0.)

# %%
building = arch_ifc.by_type("IfcBuilding")[0]
building.get_info()
# Out:
# {'id': 118,
#  'type': 'IfcBuilding',
#  'GlobalId': '0eoqdncsb8SAoZq$DYYdza',
#  'OwnerHistory': #41=IfcOwnerHistory(#38,#5,$,.NOCHANGE.,$,$,$,0),
#  'Name': '',
#  'Description': None,
#  'ObjectType': None,
#  'ObjectPlacement': #32=IfcLocalPlacement(#23678880,#31),
#  'Representation': None,
#  'LongName': '',
#  'CompositionType': 'ELEMENT',
#  'ElevationOfRefHeight': None,
#  'ElevationOfTerrain': None,
#  'BuildingAddress': #114=IfcPostalAddress($,$,$,$,(),$,$,$,$,$)}

# %%
storyes_ark = arch_ifc.by_type("IfcBuildingStorey")
for storey in storyes_ark:
    print(storey.get_info())
# Out:
# {'id': 127, 'type': 'IfcBuildingStorey', 'GlobalId': '0eoqdncsb8SAoZq$ETTygP', 'OwnerHistory': #41=IfcOwnerHistory(#38,#5,$,.NOCHANGE.,$,$,$,0), 'Name': 'Merenpinta', 'Description': None, 'ObjectType': None, 'ObjectPlacement': #125=IfcLocalPlacement(#32,#124), 'Representation': None, 'LongName': 'Merenpinta', 'CompositionType': 'ELEMENT', 'Elevation': 0.0}
# {'id': 133, 'type': 'IfcBuildingStorey', 'GlobalId': '0eoqdncsb8SAoZq$ETVUGE', 'OwnerHistory': #41=IfcOwnerHistory(#38,#5,$,.NOCHANGE.,$,$,$,0), 'Name': 'R.kerros', 'Description': None, 'ObjectType': None, 'ObjectPlacement': #132=IfcLocalPlacement(#32,#131), 'Representation': None, 'LongName': 'R.kerros', 'CompositionType': 'ELEMENT', 'Elevation': 15899.9999999986}
# {'id': 139, 'type': 'IfcBuildingStorey', 'GlobalId': '0eoqdncsb8SAoZq$ETSjH9', 'OwnerHistory': #41=IfcOwnerHistory(#38,#5,$,.NOCHANGE.,$,$,$,0), 'Name': 'K.kerros', 'Description': None, 'ObjectType': None, 'ObjectPlacement': #138=IfcLocalPlacement(#32,#137), 'Representation': None, 'LongName': 'K.kerros', 'CompositionType': 'ELEMENT', 'Elevation': 19899.9999999986}
# {'id': 145, 'type': 'IfcBuildingStorey', 'GlobalId': '0eoqdncsb8SAoZq$ETSjGa', 'OwnerHistory': #41=IfcOwnerHistory(#38,#5,$,.NOCHANGE.,$,$,$,0), 'Name': '0.kerros', 'Description': None, 'ObjectType': None, 'ObjectPlacement': #144=IfcLocalPlacement(#32,#143), 'Representation': None, 'LongName': '0.kerros', 'CompositionType': 'ELEMENT', 'Elevation': 23700.0}
# {'id': 151, 'type': 'IfcBuildingStorey', 'GlobalId': '0eoqdncsb8SAoZq$ETTO6Y', 'OwnerHistory': #41=IfcOwnerHistory(#38,#5,$,.NOCHANGE.,$,$,$,0), 'Name': '1.kerros', 'Description': None, 'ObjectType': None, 'ObjectPlacement': #150=IfcLocalPlacement(#32,#149), 'Representation': None, 'LongName': '1.kerros', 'CompositionType': 'ELEMENT', 'Elevation': 27800.0}
# {'id': 157, 'type': 'IfcBuildingStorey', 'GlobalId': '0eoqdncsb8SAoZq$ETTO8Z', 'OwnerHistory': #41=IfcOwnerHistory(#38,#5,$,.NOCHANGE.,$,$,$,0), 'Name': '2.kerros', 'Description': None, 'ObjectType': None, 'ObjectPlacement': #156=IfcLocalPlacement(#32,#155), 'Representation': None, 'LongName': '2.kerros', 'CompositionType': 'ELEMENT', 'Elevation': 32700.0000000061}
# {'id': 163, 'type': 'IfcBuildingStorey', 'GlobalId': '0eoqdncsb8SAoZq$ETSjD$', 'OwnerHistory': #41=IfcOwnerHistory(#38,#5,$,.NOCHANGE.,$,$,$,0), 'Name': '3.kerros', 'Description': None, 'ObjectType': None, 'ObjectPlacement': #162=IfcLocalPlacement(#32,#161), 'Representation': None, 'LongName': '3.kerros', 'CompositionType': 'ELEMENT', 'Elevation': 36900.0000000061}
# {'id': 169, 'type': 'IfcBuildingStorey', 'GlobalId': '0eoqdncsb8SAoZq$ETSjDh', 'OwnerHistory': #41=IfcOwnerHistory(#38,#5,$,.NOCHANGE.,$,$,$,0), 'Name': '4.kerros', 'Description': None, 'ObjectType': None, 'ObjectPlacement': #168=IfcLocalPlacement(#32,#167), 'Representation': None, 'LongName': '4.kerros', 'CompositionType': 'ELEMENT', 'Elevation': 41100.0000000061}
# {'id': 175, 'type': 'IfcBuildingStorey', 'GlobalId': '0eoqdncsb8SAoZq$ETSjI4', 'OwnerHistory': #41=IfcOwnerHistory(#38,#5,$,.NOCHANGE.,$,$,$,0), 'Name': '5.kerros', 'Description': None, 'ObjectType': None, 'ObjectPlacement': #174=IfcLocalPlacement(#32,#173), 'Representation': None, 'LongName': '5.kerros', 'CompositionType': 'ELEMENT', 'Elevation': 45300.0000000061}
# {'id': 181, 'type': 'IfcBuildingStorey', 'GlobalId': '0eoqdncsb8SAoZq$ETSjJ0', 'OwnerHistory': #41=IfcOwnerHistory(#38,#5,$,.NOCHANGE.,$,$,$,0), 'Name': '6.kerros', 'Description': None, 'ObjectType': None, 'ObjectPlacement': #180=IfcLocalPlacement(#32,#179), 'Representation': None, 'LongName': '6.kerros', 'CompositionType': 'ELEMENT', 'Elevation': 49500.0000000061}
# {'id': 187, 'type': 'IfcBuildingStorey', 'GlobalId': '0eoqdncsb8SAoZq$ETSjGN', 'OwnerHistory': #41=IfcOwnerHistory(#38,#5,$,.NOCHANGE.,$,$,$,0), 'Name': '7.kerros', 'Description': None, 'ObjectType': None, 'ObjectPlacement': #186=IfcLocalPlacement(#32,#185), 'Representation': None, 'LongName': '7.kerros', 'CompositionType': 'ELEMENT', 'Elevation': 53700.0000000061}
# {'id': 193, 'type': 'IfcBuildingStorey', 'GlobalId': '0eoqdncsb8SAoZq$ETCDRy', 'OwnerHistory': #41=IfcOwnerHistory(#38,#5,$,.NOCHANGE.,$,$,$,0), 'Name': 'IV-Kammio', 'Description': None, 'ObjectType': None, 'ObjectPlacement': #192=IfcLocalPlacement(#32,#191), 'Representation': None, 'LongName': 'IV-Kammio', 'CompositionType': 'ELEMENT', 'Elevation': 58100.0000000035}

# %%
hvac_ifc = ifcopenshell.open("C:/Users/yanpe/OneDrive - Metropolia Ammattikorkeakoulu Oy/Research/MD2MV/data/IFC/03LVI/LVI_LJ_MET.ifc")
site_lvi = hvac_ifc.by_type("IfcSite")[0]
site_lvi.get_info()
# Out:
# {'id': 31,
#  'type': 'IfcSite',
#  'GlobalId': '2Fm4WKyh10RANaa_0BW2kW',
#  'OwnerHistory': #5=IfcOwnerHistory(#8,#9,$,.NOCHANGE.,$,$,$,1562874076),
#  'Name': 'Metropolia',
#  'Description': 'Testi',
#  'ObjectType': None,
#  'ObjectPlacement': #32=IfcLocalPlacement($,#28),
#  'Representation': None,
#  'LongName': None,
#  'CompositionType': 'ELEMENT',
#  'RefLatitude': (0, 0, 0, 0),
#  'RefLongitude': (0, 0, 0, 0),
#  'RefElevation': 0.0,
#  'LandTitleNumber': None,
#  'SiteAddress': None}

# %%
building_lvi = hvac_ifc.by_type("IfcBuilding")[0]
building_lvi.get_info()
# Out:
# {'id': 34,
#  'type': 'IfcBuilding',
#  'GlobalId': '0DgGiPlffFo9_7V0ZN1flI',
#  'OwnerHistory': #5=IfcOwnerHistory(#8,#9,$,.NOCHANGE.,$,$,$,1562874076),
#  'Name': 'mc-building',
#  'Description': None,
#  'ObjectType': None,
#  'ObjectPlacement': #35=IfcLocalPlacement($,#28),
#  'Representation': None,
#  'LongName': None,
#  'CompositionType': 'ELEMENT',
#  'ElevationOfRefHeight': None,
#  'ElevationOfTerrain': None,
#  'BuildingAddress': None}

# %%
storyes_lvi = hvac_ifc.by_type("IfcBuildingStorey")
for storey in storyes_lvi:
    print(storey.get_info())
# Out:
# {'id': 38, 'type': 'IfcBuildingStorey', 'GlobalId': '0w4y3u2_fFXf$tPPWTaivY', 'OwnerHistory': #5=IfcOwnerHistory(#8,#9,$,.NOCHANGE.,$,$,$,1562874076), 'Name': 'Kellari', 'Description': None, 'ObjectType': None, 'ObjectPlacement': #39=IfcLocalPlacement(#35,#37), 'Representation': None, 'LongName': None, 'CompositionType': 'ELEMENT', 'Elevation': 19900.0}
# {'id': 471111, 'type': 'IfcBuildingStorey', 'GlobalId': '3OElruOf1EA9xZz8W4zq6h', 'OwnerHistory': #5=IfcOwnerHistory(#8,#9,$,.NOCHANGE.,$,$,$,1562874076), 'Name': '0 kerros', 'Description': None, 'ObjectType': None, 'ObjectPlacement': #471112=IfcLocalPlacement(#35,#471110), 'Representation': None, 'LongName': None, 'CompositionType': 'ELEMENT', 'Elevation': 23700.0}
# {'id': 952737, 'type': 'IfcBuildingStorey', 'GlobalId': '3_Ijz3EZ1B6BYQpbCLflPr', 'OwnerHistory': #5=IfcOwnerHistory(#8,#9,$,.NOCHANGE.,$,$,$,1562874076), 'Name': '1.kerros', 'Description': None, 'ObjectType': None, 'ObjectPlacement': #952738=IfcLocalPlacement(#35,#952736), 'Representation': None, 'LongName': None, 'CompositionType': 'ELEMENT', 'Elevation': 27800.0}
# {'id': 1613518, 'type': 'IfcBuildingStorey', 'GlobalId': '0_ItFaASP9zeuscyu9pjcA', 'OwnerHistory': #5=IfcOwnerHistory(#8,#9,$,.NOCHANGE.,$,$,$,1562874076), 'Name': '2.kerros', 'Description': None, 'ObjectType': None, 'ObjectPlacement': #1613519=IfcLocalPlacement(#35,#1613517), 'Representation': None, 'LongName': None, 'CompositionType': 'ELEMENT', 'Elevation': 32700.0}
# {'id': 2383850, 'type': 'IfcBuildingStorey', 'GlobalId': '2LLe$zHnrBGAzc6F4ROaDt', 'OwnerHistory': #5=IfcOwnerHistory(#8,#9,$,.NOCHANGE.,$,$,$,1562874076), 'Name': '3.kerros', 'Description': None, 'ObjectType': None, 'ObjectPlacement': #2383851=IfcLocalPlacement(#35,#2383849), 'Representation': None, 'LongName': None, 'CompositionType': 'ELEMENT', 'Elevation': 36900.0}
# {'id': 3134010, 'type': 'IfcBuildingStorey', 'GlobalId': '1$fhcZ4KL4_A3jNpf$NaCl', 'OwnerHistory': #5=IfcOwnerHistory(#8,#9,$,.NOCHANGE.,$,$,$,1562874076), 'Name': '4.kerros', 'Description': None, 'ObjectType': None, 'ObjectPlacement': #3134011=IfcLocalPlacement(#35,#3134009), 'Representation': None, 'LongName': None, 'CompositionType': 'ELEMENT', 'Elevation': 41100.0}
# {'id': 3881292, 'type': 'IfcBuildingStorey', 'GlobalId': '2ZIrB$BHz1$hO$xPkkqhDm', 'OwnerHistory': #5=IfcOwnerHistory(#8,#9,$,.NOCHANGE.,$,$,$,1562874076), 'Name': '5.kerros', 'Description': None, 'ObjectType': None, 'ObjectPlacement': #3881293=IfcLocalPlacement(#35,#3881291), 'Representation': None, 'LongName': None, 'CompositionType': 'ELEMENT', 'Elevation': 45300.0}
# {'id': 4765043, 'type': 'IfcBuildingStorey', 'GlobalId': '0$djl66NH5LfZw3nwbBPdB', 'OwnerHistory': #5=IfcOwnerHistory(#8,#9,$,.NOCHANGE.,$,$,$,1562874076), 'Name': '6.kerros', 'Description': None, 'ObjectType': None, 'ObjectPlacement': #4765044=IfcLocalPlacement(#35,#4765042), 'Representation': None, 'LongName': None, 'CompositionType': 'ELEMENT', 'Elevation': 49500.0}
# {'id': 5487123, 'type': 'IfcBuildingStorey', 'GlobalId': '2L2ED60uf9tvGoLYsDwr3Z', 'OwnerHistory': #5=IfcOwnerHistory(#8,#9,$,.NOCHANGE.,$,$,$,1562874076), 'Name': '7.kerros', 'Description': None, 'ObjectType': None, 'ObjectPlacement': #5487124=IfcLocalPlacement(#35,#5487122), 'Representation': None, 'LongName': None, 'CompositionType': 'ELEMENT', 'Elevation': 53700.0}

# %%
matches = []
matched_storeys_count = 0

# 1. Match Sites and Buildings
if len(arch_data['sites'])==1 and len(hvac_iv_data['sites'])==1:
    for a_name, a_uri in arch_data['sites'].items():
        for h_name, h_uri in hvac_iv_data['sites'].items():
            matches.append((a_uri, h_uri))

if len(arch_data['buildings'])==1 and len(hvac_iv_data['buildings'])==1:
    for a_name, a_uri in arch_data['buildings'].items():
        for h_name, h_uri in hvac_iv_data['buildings'].items():
            matches.append((a_uri, h_uri))

# 2. Match Storeys (The Anchor)
print("\n--- Aligning Storeys ---")
for a_name, a_uri in arch_data['storeys'].items():
    a_id = a_name.split("_")[-1]
    a_storey = arch_ifc.by_id(int(a_id))
    a_elevation = a_storey.Elevation
    best_match_uri = None    
    
    for h_name, h_uri in hvac_iv_data['storeys'].items():
        # match with elevation difference consideration
        h_id = h_name.split("_")[-1]
        h_storey = hvac_ifc.by_id(int(h_id))
        h_elevation = h_storey.Elevation

        # Calculate elevation difference
        elevation_diff = abs(a_elevation - h_elevation)
        if elevation_diff < 0.1:  # Threshold for elevation match
            best_match_uri = h_uri
    
    if best_match_uri:
        matches.append((a_uri, best_match_uri))
        matched_storeys_count += 1
        # Helper to get the name of the matched HVAC storey for printing
        h_matched_name = [k for k, v in hvac_iv_data['storeys'].items() if v == best_match_uri][0]
        print(f"MATCH: Storey '{a_name}' == '{h_matched_name}'")

if matched_storeys_count > 0:
    print(f"\nTotal matched storeys: {matched_storeys_count}")   
            
else:
    print("\nWarning: No storeys matched. Aborting Site/Building linkage to avoid false positives.")
# Out:
# --- Aligning Storeys ---
# MATCH: Storey 'IfcBuildingStorey_157' == 'IfcBuildingStorey_1613518'
# MATCH: Storey 'IfcBuildingStorey_163' == 'IfcBuildingStorey_2383850'
# MATCH: Storey 'IfcBuildingStorey_169' == 'IfcBuildingStorey_3134010'
# MATCH: Storey 'IfcBuildingStorey_181' == 'IfcBuildingStorey_4765043'
# MATCH: Storey 'IfcBuildingStorey_175' == 'IfcBuildingStorey_3881292'
# MATCH: Storey 'IfcBuildingStorey_139' == 'IfcBuildingStorey_38'
# MATCH: Storey 'IfcBuildingStorey_145' == 'IfcBuildingStorey_471111'
# MATCH: Storey 'IfcBuildingStorey_187' == 'IfcBuildingStorey_5487123'
# MATCH: Storey 'IfcBuildingStorey_151' == 'IfcBuildingStorey_952737'
#
# Total matched storeys: 9

# %%
# 4. Generate Linkset
linkset = Graph()
linkset.bind("owl", OWL)
linkset.bind("bot", BOT) # Useful if you want to extend with bot types later

print("\n--- Generating 'links.ttl' ---")
for arch_uri, hvac_uri in matches:
    linkset.add((arch_uri, OWL.sameAs, hvac_uri))

linkset.serialize(destination="links.ttl", format="ttl")
print("Done.")
# Out:
# --- Generating 'links.ttl' ---
# Done.
